# %% [markdown]
# <a href="https://colab.research.google.com/github/dbj086/STATS/blob/main/Statistics_Advance_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###THEORY QUESTION###
# ##Q1) What is a random variable in probability theory ?
#
# Ans:In probability theory, a **random variable** is a variable that takes on different values based on the outcome of a random event or experiment. It is a function that assigns a numerical value to each possible outcome in a sample space.
#
# There are two main types of random variables:
#
# 1. **Discrete Random Variable**: This type takes on a finite or countably infinite set of values. For example, the number of heads in a series of coin flips (which could be 0, 1, or 2 heads if flipping two coins) is a discrete random variable.
#
# 2. **Continuous Random Variable**: This type can take on an infinite number of values within a given range. For example, the height of a randomly chosen person is a continuous random variable because it could be any value within a certain range, like between 150 cm and 200 cm.
#
# Random variables are often denoted by letters such as \(X\), \(Y\), or \(Z\). The probability distribution of a random variable describes the likelihood of different outcomes.
#
# - For discrete random variables, this is often represented as a **probability mass function** (PMF), which gives the probability of each possible value.
# - For continuous random variables, the **probability density function** (PDF) is used, and probabilities are derived by integrating the PDF over a range of values.
#
# ##Q2)What are the types of random variables ?
#
# Ans:Random variables can be classified into two main types:
#
# ### 1. **Discrete Random Variables**
# These random variables can take on a **finite** or **countably infinite** set of values. The possible values of a discrete random variable can often be listed or counted.
#
# - **Examples**:
#   - The number of heads when flipping a coin multiple times.
#   - The number of cars passing a checkpoint in an hour.
#   - The number of customers arriving at a store in a given time period.
#
#   Discrete random variables are usually associated with a **probability mass function (PMF)**, which gives the probability that the random variable takes a particular value.
#
# ### 2. **Continuous Random Variables**
# These random variables can take on an **infinite** number of values within a given range. The values are uncountable, and they are typically measured rather than counted.
#
# - **Examples**:
#   - The height of a randomly selected person.
#   - The time it takes for a computer to run a program.
#   - The temperature on a given day.
#
#   Continuous random variables are described by a **probability density function (PDF)**. For continuous variables, the probability of any exact value is zero, and probabilities are instead computed over intervals (e.g., the probability that a value falls between two specific points).
#
# ### Additional Classifications:
# While the primary distinction is between discrete and continuous, random variables can also be described by their **nature of the distribution**:
#
# - **Bernoulli Random Variable**: A random variable that has only two possible outcomes, often 0 or 1 (e.g., success or failure, yes or no). It’s a special case of a discrete random variable.
#
# - **Binomial Random Variable**: This is a discrete random variable that represents the number of successes in a fixed number of independent Bernoulli trials.
#
# - **Normal (Gaussian) Random Variable**: A continuous random variable that follows a normal distribution, commonly used in statistics to model a wide variety of phenomena.
#
# - **Poisson Random Variable**: A discrete random variable that models the number of events occurring in a fixed interval of time or space, given that these events occur with a known constant mean rate and independently of the time since the last event.
#
# ##Q3)What is the difference between discrete and continuous distributions ?
#
# Ans:The main difference between **discrete** and **continuous distributions** is:
#
# - **Discrete distributions** involve random variables that can take on
# **countable** distinct values (e.g., 0, 1, 2, etc.), and probability is assigned to each specific value.
#
# - **Continuous distributions** involve random variables that can take on an **uncountable** range of values (e.g., any real number within a range), and probability is assigned to intervals of values rather than specific ones.
#
#  **Discrete** Countable values, specific probabilities for each value.
# **Continuous** Uncountable values, probability over ranges or intervals.
#
# ##Q4) What are probability distribution functions (PDF) ?
#
# Ans:A **Probability Distribution Function (PDF)** is a function that describes the likelihood of different outcomes for a random variable. For **discrete variables**, it is called the **Probability Mass Function (PMF)**, and for **continuous variables**, it gives the probability density over intervals. The key properties are that the sum (discrete) or the area (continuous) of all possible outcomes equals 1.
#
# In simple terms, it tells you how probabilities are distributed over the possible values of a random variable.
#
# ##Q5)How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF) ?
#
# Ans:The main difference between a **Probability Distribution Function (PDF)** and a **Cumulative Distribution Function (CDF)** is in what they represent:
#
# 1. **PDF (Probability Distribution Function)**:
#    - Describes the likelihood of a random variable taking a specific value (for discrete variables) or a value within an interval (for continuous variables).
#    - For continuous variables, the PDF gives the probability density, not the actual probability of a specific value.
#    - The area under the PDF curve between two points gives the probability of the random variable falling within that range.
#
# 2. **CDF (Cumulative Distribution Function)**:
#    - Represents the **cumulative probability** that a random variable takes a value less than or equal to a specific value.
#    - It gives the accumulated probability up to a certain point.
#    - The CDF is always non-decreasing and ranges from 0 to 1.
#
# ### Key Differences:
# - **PDF** gives the probability density (height of the curve at a point).
# - **CDF** gives the cumulative probability (area under the curve up to a point).
#
# ##Q6) What is a discrete uniform distribution ?
#
# Ans:A **Discrete Uniform Distribution** is a type of probability distribution where all outcomes of a discrete random variable have the same probability of occurring.
#
# ### Key Characteristics:
# - The random variable can take **finite** values.
# - Each possible outcome has the **same probability**.
# - The distribution is "uniform" because all probabilities are equal.
#
# ### Example:
# For a fair six-sided die, the possible outcomes are 1, 2, 3, 4, 5, and 6. Each outcome has an equal probability of occurring:
# \[
# P(X = x) = \frac{1}{6} \quad \text{for} \quad x \in \{1, 2, 3, 4, 5, 6\}
# \]
# This is a **discrete uniform distribution** because each side of the die has the same probability of showing up.
#
# ### General Formula:
# For a discrete uniform distribution where the random variable \( X \) can take \( n \) values (say \( x_1, x_2, \dots, x_n \)), the probability of each outcome is:
# \[
# P(X = x_i) = \frac{1}{n} \quad \text{for each } i \in \{1, 2, \dots, n\}
# \]
#
# This distribution is often used when all outcomes in a finite sample space are equally likely.
#
# ##Q7)What are the key properties of a Bernoulli distribution ?
#
# Ans:The **Bernoulli Distribution** is a discrete probability distribution that describes a random experiment with exactly **two possible outcomes**: success (often denoted as 1) or failure (denoted as 0). It's often used to model scenarios like coin flips, yes/no questions, or pass/fail outcomes.
#
# ### Key Properties of a Bernoulli Distribution:
#
# 1. **Two Outcomes**:
#    - The random variable \( X \) can take only two values: 0 (failure) and 1 (success).
#
# 2. **Parameter \( p \)**:
#    - \( p \) is the probability of success (i.e., \( P(X = 1) = p \)).
#    - The probability of failure is \( 1 - p \) (i.e., \( P(X = 0) = 1 - p \)).
#
# 3. **Probability Mass Function (PMF)**:
#    The PMF of a Bernoulli random variable \( X \) is:
#    \[
#    P(X = 1) = p \quad \text{and} \quad P(X = 0) = 1 - p
#    \]
#    where \( 0 \leq p \leq 1 \).
#
# 4. **Mean (Expected Value)**:
#    The mean or expected value \( E[X] \) of a Bernoulli distribution is:
#    \[
#    E[X] = p
#    \]
#
# 5. **Variance**:
#    The variance \( \text{Var}(X) \) of a Bernoulli distribution is:
#    \[
#    \text{Var}(X) = p(1 - p)
#    \]
#
# 6. **Support**:
#    The distribution is supported on the set \( \{0, 1\} \), meaning the random variable can only take values 0 or 1.
#
# 7. **Applications**:
#    - The Bernoulli distribution is used to model binary or dichotomous events (like success/failure, pass/fail, heads/tails).
#    - It's the basis for the **Binomial Distribution**, which models the number of successes in a fixed number of independent Bernoulli trials.
#
# ##Q8)What is the binomial distribution, and how is it used in probability ?
#
# Ans:The **Binomial Distribution** is a discrete probability distribution that models the number of **successes** in a fixed number of independent **Bernoulli trials** (experiments with two outcomes: success or failure). Each trial has the same probability of success.
#
# ### Key Characteristics of the Binomial Distribution:
# 1. **Fixed Number of Trials**:
#    - The experiment is repeated \( n \) times (e.g., flipping a coin 10 times, rolling a die 10 times).
#
# 2. **Two Outcomes Per Trial**:
#    - Each trial results in either a success (denoted as 1) or a failure (denoted as 0).
#
# 3. **Constant Probability of Success**:
#    - The probability of success \( p \) is the same for each trial, and the probability of failure is \( 1 - p \).
#
# 4. **Independent Trials**:
#    - The outcome of one trial does not affect the outcomes of other trials (i.e., trials are independent).
#
# ### Binomial Distribution Formula:
# The probability of observing exactly \( k \) successes (out of \( n \) trials) in a binomial experiment is given by the **Binomial Probability Mass Function (PMF)**:
#
# \[
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# \]
#
# Where:
# - \( n \) = number of trials.
# - \( k \) = number of successes.
# - \( p \) = probability of success on a single trial.
# - \( \binom{n}{k} = \frac{n!}{k!(n - k)!} \) is the **binomial coefficient**, representing the number of ways to choose \( k \) successes from \( n \) trials.
#
# ### Key Properties:
# 1. **Mean (Expected Value)**:
#    \[
#    E[X] = n \cdot p
#    \]
#    The expected number of successes is \( n \) times the probability of success.
#
# 2. **Variance**:
#    \[
#    \text{Var}(X) = n \cdot p \cdot (1 - p)
#    \]
#    The variance of the binomial distribution depends on the number of trials and the probability of success.
#
# 3. **Standard Deviation**:
#    \[
#    \text{SD}(X) = \sqrt{n \cdot p \cdot (1 - p)}
#    \]
#
# ### When to Use the Binomial Distribution:
# - When you have a **fixed number of trials** (\( n \)).
# - Each trial has only two possible outcomes (success or failure).
# - The probability of success (\( p \)) is the same for each trial.
# - The trials are **independent**.
#
# ### Example Use Case:
# Suppose you flip a fair coin 10 times (so \( n = 10 \), and \( p = 0.5 \)). The binomial distribution can be used to calculate the probability of getting exactly 7 heads (successes):
# \[
# P(X = 7) = \binom{10}{7} (0.5)^7 (0.5)^{3} = \binom{10}{7} (0.5)^{10}
# \]
# Where \( \binom{10}{7} \) is the number of ways to get 7 heads in 10 flips.
#
# ### Applications of the Binomial Distribution:
# - **Quality control**: To find the probability of defective items in a batch.
# - **Survey sampling**: To model the probability of a certain number of people answering "yes" in a survey.
# - **Marketing**: To calculate the probability of a certain number of customers buying a product based on conversion rates.
#
#
# ##Q9) What is the Poisson distribution and where is it applied ?
#
# Ans:The **Poisson distribution** is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space, given that these events happen independently at a constant average rate.
#
# ### Applications:
# - **Traffic flow**: Modeling the number of cars passing an intersection in a given time.
# - **Call centers**: Modeling the number of incoming calls per minute or hour.
# - **Manufacturing**: Modeling the number of defects in a production process.
# - **Natural events**: Modeling rare occurrences like meteorite strikes or earthquakes.
#
# It's used when events are rare, occur independently, and happen at a constant rate.
#
# ##Q10)What is a continuous uniform distribution ?
#
# Ans:A **Continuous Uniform Distribution** is a probability distribution where all values within a certain interval are equally likely to occur. The distribution is defined over a continuous range, meaning the random variable can take any value within the interval.
#
# ### Key Features:
# 1. **Interval**:
#    - The distribution is defined over an interval \( [a, b] \), where \( a \) is the lower bound and \( b \) is the upper bound. Any value within this interval has an equal chance of occurring.
#
# 2. **Probability Density Function (PDF)**:
#    The PDF for a continuous uniform distribution is constant between \( a \) and \( b \), and is given by:
#    \[
#    f(x) = \frac{1}{b - a} \quad \text{for} \quad a \leq x \leq b
#    \]
#    Outside this interval, the probability is 0.
#
# 3. **Mean (Expected Value)**:
#    The expected value \( E[X] \) of a continuous uniform distribution is the midpoint of the interval:
#    \[
#    E[X] = \frac{a + b}{2}
#    \]
#
# 4. **Variance**:
#    The variance \( \text{Var}(X) \) of the distribution is:
#    \[
#    \text{Var}(X) = \frac{(b - a)^2}{12}
#    \]
#
# ### When to Use:
# - **Equally likely outcomes**: Use this distribution when every value within a specified range is equally likely. For example, if you randomly select a point between 0 and 10, each value within this range has the same probability of being selected.
#
# ### Example:
# If \( X \) follows a continuous uniform distribution between 0 and 5, the PDF is:
# \[
# f(x) = \frac{1}{5 - 0} = \frac{1}{5} \quad \text{for} \quad 0 \leq x \leq 5
# \]
# This means that any value between 0 and 5 has an equal chance of being chosen.
#
# ##Q11) What are the characteristics of a normal distribution ?
#
# Ans:The **Normal Distribution** has the following key characteristics:
#
# 1. **Symmetry**: It's symmetric around the mean (\( \mu \)), meaning the left and right sides are identical.
# 2. **Bell-Shaped Curve**: The distribution has a bell shape, peaking at the mean.
# 3. **Mean = Median = Mode**: All are equal and located at the center of the distribution.
# 4. **Defined by Two Parameters**: The mean (\( \mu \)) and standard deviation (\( \sigma \)) control its center and spread.
# 5. **68-95-99.7 Rule**: 68% of values lie within 1 standard deviation, 95% within 2, and 99.7% within 3.
# 6. **Asymptotic**: The tails approach the horizontal axis but never touch it.
# 7. **Probability Density Function (PDF)**: Described by the formula \( f(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{(x - \mu)^2}{2\sigma^2}} \).
#
# It is widely used in statistics, natural sciences, and many real-world applications.
#
# ##Q12)What is the standard normal distribution, and why is it important ?
#
# Ans:The **Standard Normal Distribution** is a special case of the normal distribution where the **mean** is 0 and the **standard deviation** is 1. It is often denoted as **\( Z \)-distribution**.
#
# ### Key Characteristics of the Standard Normal Distribution:
# 1. **Mean \( \mu = 0 \)**: The distribution is centered at 0.
# 2. **Standard Deviation \( \sigma = 1 \)**: The spread of the distribution is fixed at 1.
# 3. **Symmetry**: Like any normal distribution, it is symmetric around the mean (0).
# 4. **Bell-Shaped Curve**: It has the same bell-shaped curve as any normal distribution.
#
# ### Why is the Standard Normal Distribution Important?
#
# 1. **Z-Scores**:
#    - The standard normal distribution allows us to use **z-scores**, which standardize any normal distribution to compare different data sets.
#    - A **z-score** is a measure of how many standard deviations a particular value is away from the mean, calculated as:
#    \[
#    Z = \frac{X - \mu}{\sigma}
#    \]
#    This transformation allows any normally distributed data to be expressed in terms of the standard normal distribution.
#
# 2. **Simplification**:
#    - With the standard normal distribution, probabilities and statistical analysis are simplified. Tables for the standard normal distribution (Z-tables) are widely available, allowing quick lookups for probabilities.
#    - It enables us to calculate the probabilities for any normal distribution by transforming the data into a standard normal form using the z-score formula.
#
# 3. **Application in Hypothesis Testing**:
#    - In **hypothesis testing** (e.g., z-tests), the standard normal distribution is often used to assess the significance of results.
#
# 4. **Central Limit Theorem**:
#    - According to the **central limit theorem**, the sampling distribution of the sample mean for a large number of independent observations will approach a normal distribution, and it can be standardized to the standard normal distribution for hypothesis testing and confidence intervals.
#
# ##Q13)What is the Central Limit Theorem (CLT), and why is it critical in statistics)  ?
#
# Ans:The **Central Limit Theorem (CLT)** is a fundamental concept in statistics that states:
#
# - **Regardless of the population's distribution**, the **sampling distribution of the sample mean** will approach a **normal distribution** as the sample size increases, **provided the samples are independent and identically distributed (i.i.d.)**.
# - This is true for **any population distribution** (whether normal or not), as long as the sample size is large enough (typically \( n \geq 30 \)).
#
# ### Key Points of the CLT:
# 1. **Sample Mean Distribution**: If you take multiple random samples from a population and calculate their means, those sample means will form a distribution. As the sample size increases, this distribution of sample means will approximate a normal distribution, even if the original population is not normally distributed.
#
# 2. **Normality**: The larger the sample size, the more the distribution of sample means will resemble a normal distribution, regardless of the shape of the original population.
#
# 3. **Mean of the Sample Mean**: The mean of the sampling distribution of the sample mean will be equal to the population mean (\( \mu \)).
#
# 4. **Standard Deviation (Standard Error)**: The standard deviation of the sampling distribution (called the **standard error**) will be equal to the population standard deviation (\( \sigma \)) divided by the square root of the sample size (\( \sqrt{n} \)):
#
#    \[
#    \text{Standard Error} = \frac{\sigma}{\sqrt{n}}
#    \]
#
# ### Why the Central Limit Theorem is Critical:
# 1. **Facilitates Inference**:
#    - The CLT allows statisticians to make inferences about a population using sample data. Even if the underlying population is not normally distributed, the sample mean distribution will approximate normality for sufficiently large samples, making hypothesis testing and confidence intervals possible.
#
# 2. **Foundation for Statistical Methods**:
#    - Many statistical methods (e.g., z-tests, t-tests, confidence intervals) rely on the assumption of normality. Thanks to the CLT, these methods can be applied to large sample sizes regardless of the population’s distribution.
#
# 3. **Justifies Approximation to Normal Distribution**:
#    - It justifies why, in many cases, statistical procedures based on the normal distribution work well even if the population is not normal, as long as the sample size is large enough.
#
# 4. **Simplifies Analysis**:
#    - By ensuring that sample means approach a normal distribution, the CLT makes it easier to analyze and interpret data, even when the exact distribution of the population is unknown.
#
# ### Example:
# - If you're measuring the average height of individuals in a city, the heights of the individuals may not follow a normal distribution. However, if you take many random samples of 30 people (or more) and calculate their average heights, the distribution of those sample means will approximate a normal distribution, even if the original data is not normal.
#
# ##Q14)How does the Central Limit Theorem relate to the normal distribution ?
#
# Ans:The **Central Limit Theorem (CLT)** is directly related to the **normal distribution** because it explains why the sampling distribution of the sample mean tends to follow a **normal distribution** under certain conditions, even when the population from which the sample is drawn does not follow a normal distribution.
#
# ### The Relationship:
#
# 1. **Sampling Distribution of the Sample Mean**:
#    - The CLT states that when you take a **large number of random samples** from a population and calculate the mean of each sample, the distribution of those sample means will approach a **normal distribution**, regardless of the original population's distribution.
#    - This result holds as the sample size increases (typically, \( n \geq 30 \) is considered sufficiently large).
#
# 2. **Why This Matters**:
#    - Even if the population data is **skewed**, **uniform**, or **has some other non-normal distribution**, the **sampling distribution of the sample mean** will **tend to become normal** as the sample size increases.
#    - This is important because many statistical methods, such as hypothesis testing and confidence intervals, rely on the assumption of normality. The CLT provides a foundation for using these methods even when the underlying data is not normal.
#
# 3. **Approaching Normal Distribution**:
#    - As the sample size grows, the sampling distribution of the sample mean becomes **more bell-shaped and symmetric**, resembling the **normal distribution** more closely.
#    - This allows us to use the normal distribution to calculate probabilities and make inferences about the population mean, even if the population itself is not normally distributed.
#
# 4. **Key Parameters (Mean and Standard Error)**:
#    - The **mean** of the sampling distribution of the sample mean is equal to the **mean** of the population (\( \mu \)).
#    - The **standard deviation** of the sampling distribution (called the **standard error**) is \( \frac{\sigma}{\sqrt{n}} \), where \( \sigma \) is the population standard deviation and \( n \) is the sample size.
#
# ### Example to Illustrate:
# - Suppose you're studying the heights of adult women in a country, and the height distribution is not normal (perhaps it’s skewed). If you take multiple samples of 50 women and compute the sample mean height for each, the distribution of those means will gradually approach a normal distribution as the number of samples increases, due to the CLT. This means you can apply normal distribution-based statistical techniques, even if the original height data is not normal.
#
# ##Q15) What is the application of Z statistics in hypothesis testing ?
#
# Ans:In hypothesis testing, **Z-statistics** are used to determine whether a sample mean significantly differs from a population mean. The Z-statistic is calculated to compare the sample statistic to the population parameter, using the population standard deviation and sample size. If the Z-statistic exceeds a critical value from the Z-distribution (based on the chosen significance level), the null hypothesis is rejected. Z-tests are commonly used when the population standard deviation is known and the sample size is large (typically \( n > 30 \)).
#
# ##Q16) How do you calculate a Z-score, and what does it represent ?
#
# Ans:A **Z-score** represents how many standard deviations a data point (or sample statistic) is from the mean of a population or sample. It is used to standardize scores, allowing comparisons across different datasets or distributions.
#
# ### **Formula for Z-Score:**
#
# The Z-score is calculated using the following formula:
#
# \[
# Z = \frac{X - \mu}{\sigma}
# \]
#
# Where:
# - \( X \) is the value or data point you are analyzing.
# - \( \mu \) is the mean of the population or sample.
# - \( \sigma \) is the standard deviation of the population or sample.
#
# ### **Interpretation of a Z-Score:**
# - **Z = 0**: The data point is exactly at the mean.
# - **Z > 0**: The data point is above the mean.
# - **Z < 0**: The data point is below the mean.
# - **Z = 2**: The data point is 2 standard deviations above the mean.
# - **Z = -1**: The data point is 1 standard deviation below the mean.
#
# ### **What Does the Z-Score Represent?**
# - The Z-score tells you **how far** a particular value is from the mean, in terms of the standard deviation.
# - It allows for comparing values across different distributions, even if those distributions have different means and standard deviations.
#
# ##Q17) What are point estimates and interval estimates in statistics ?
#
# Ans:In statistics, **point estimates** and **interval estimates** are two methods used to estimate population parameters based on sample data.
#
# ### **Point Estimate**:
# - A **point estimate** is a single value used to estimate an unknown population parameter.
# - It is typically the **sample statistic** (such as the sample mean, sample proportion, etc.) that serves as the best guess for the population parameter.
#
#   **Example**: If you take a sample of 50 students' heights and calculate the average height of the sample as 160 cm, that 160 cm is a **point estimate** of the population mean height.
#
#   **Key Features**:
#   - It provides a **single value** estimate.
#   - It does not give any information about the uncertainty or variability of the estimate.
#
# ---
#
# ### **Interval Estimate**:
# - An **interval estimate** provides a range of values within which the population parameter is likely to fall. It accounts for uncertainty and variability by providing a **confidence interval**.
# - The interval is usually constructed using a **point estimate** along with a margin of error, which is based on sample variability and the desired confidence level (e.g., 95% confidence).
#
#   **Example**: If you estimate that the average height of students is between 158 cm and 162 cm with 95% confidence, this range is an **interval estimate** of the population mean.
#
#   **Key Features**:
#   - It provides a **range** (upper and lower bounds) within which the true population parameter is likely to lie.
#   - It includes a **level of confidence** (e.g., 95%, 99%) indicating the likelihood that the interval contains the true parameter.
#
# ---
#
# ##Q18) What is the significance of confidence intervals in statistical analysis ?
#
# Ans:**Confidence intervals (CIs)** are crucial in statistical analysis because they provide a **range of values** within which we can be confident that the **true population parameter** lies, based on the sample data.
#
# ### **Significance of Confidence Intervals**:
#
# 1. **Quantify Uncertainty**:
#    - Confidence intervals give us a measure of the **uncertainty** around a sample estimate. Rather than providing just a point estimate (which might be imprecise), a CI provides a **range** of plausible values for the population parameter.
#    - For example, a 95% confidence interval means we are 95% confident that the true population parameter lies within that range.
#
# 2. **Decision Making**:
#    - CIs help in decision-making by allowing us to understand the **precision** of our estimates. A narrower confidence interval indicates more precise estimates, while a wider one suggests greater uncertainty.
#    - They are used in fields like medicine, economics, and social sciences to inform policies, treatments, or predictions.
#
# 3. **Statistical Significance**:
#    - A confidence interval can help assess the **statistical significance** of a result. If a CI for a difference (e.g., between two means) does not include zero, it suggests the difference is statistically significant.
#    - For example, if the 95% CI for the difference between two means does not include zero, we can conclude that the difference is significant at the 5% level.
#
# 4. **Interpretation**:
#    - The **confidence level** (e.g., 95% or 99%) reflects how confident we are that the interval includes the true parameter. A 95% CI suggests that if we were to take many samples and compute the CIs each time, about 95% of them would contain the true population parameter.
#
# 5. **Provides More Information Than Point Estimates**:
#    - A **point estimate** gives only one value, but a **confidence interval** provides a **range of values** along with a level of confidence, offering more insight into the reliability of the estimate.
#
# 6. **Broad Applicability**:
#    - Confidence intervals are used in **hypothesis testing**, **regression analysis**, **survey research**, **clinical trials**, and many other areas of statistics.
#
# ---
#
# ##Q19)What is the relationship between a Z-score and a confidence interval ?
#
# Ans:The **relationship between a Z-score and a confidence interval** lies in the fact that the Z-score is used to calculate the **margin of error** for constructing a **confidence interval (CI)**, particularly when the population standard deviation is known.
#
# ### Key Concepts:
# 1. **Z-Score**:
#    - The Z-score represents the number of **standard deviations** a data point or statistic is away from the mean of a distribution.
#    - For a confidence interval, the Z-score corresponds to the critical value for a specific confidence level, reflecting how many standard deviations we need to go to capture a given percentage of the data.
#
# 2. **Confidence Interval**:
#    - A confidence interval provides a range within which we expect the population parameter (such as the population mean) to lie, based on sample data.
#    - The **confidence level** (e.g., 95% or 99%) defines how confident we are that the interval contains the true population parameter.
#
# ### **Using Z-Score to Calculate a Confidence Interval**:
#
# When constructing a confidence interval for a population mean using the **Z-distribution** (typically when the sample size is large or the population standard deviation is known), the formula is:
#
# \[
# \text{CI} = \bar{X} \pm Z_{\alpha/2} \times \frac{\sigma}{\sqrt{n}}
# \]
#
# Where:
# - \( \bar{X} \) is the sample mean.
# - \( Z_{\alpha/2} \) is the **Z-score** corresponding to the confidence level (e.g., 1.96 for 95% confidence).
# - \( \sigma \) is the population standard deviation.
# - \( n \) is the sample size.
#
# ### How Z-Score Relates to Confidence Intervals:
# - **Z-Score for Confidence Levels**: The Z-score used in this formula corresponds to the **critical value** that marks the boundary of the confidence interval. For example:
#   - For a **95% confidence level**, the Z-score is approximately **1.96**, meaning we expect the true population mean to fall within 1.96 standard deviations of the sample mean, 95% of the time.
#   - For a **99% confidence level**, the Z-score is approximately **2.576**, meaning we expect the true population mean to fall within 2.576 standard deviations of the sample mean, 99% of the time.
#
# - **Margin of Error**: The term \( Z_{\alpha/2} \times \frac{\sigma}{\sqrt{n}} \) in the CI formula is the **margin of error**. It represents how much the sample mean can deviate from the true population mean. The Z-score helps determine the **width** of the confidence interval — a larger Z-score (for a higher confidence level) results in a wider interval, indicating more uncertainty.
#
# ### **Example**:
# Let’s say you have a sample mean height (\( \bar{X} \)) of 170 cm, the population standard deviation (\( \sigma \)) is 10 cm, and the sample size (\( n \)) is 100. For a 95% confidence interval:
#
# - The Z-score for a 95% confidence level is **1.96**.
# - The formula for the confidence interval is:
#   \[
#   \text{CI} = 170 \pm 1.96 \times \frac{10}{\sqrt{100}}
#   \]
#   \[
#   \text{CI} = 170 \pm 1.96 \times 1
#   \]
#   \[
#   \text{CI} = 170 \pm 1.96
#   \]
#   So, the **95% confidence interval** is **(168.04, 171.96)**.
#
# This means you are 95% confident that the true population mean height lies between 168.04 cm and 171.96 cm.
#
# ##Q20) How are Z-scores used to compare different distributions ?
#
# Ans:**Z-scores** are a powerful tool for comparing values from different distributions because they **standardize** data points, making them comparable regardless of the original units, scale, or distribution. Here's how Z-scores help in comparing different distributions:
#
# ### **How Z-Scores Standardize Data**:
# - A **Z-score** tells you how many **standard deviations** a particular value is from the **mean** of the distribution.
# - The formula for a Z-score is:
#
#   \[
#   Z = \frac{X - \mu}{\sigma}
#   \]
#
#   Where:
#   - \( X \) is the data point you're comparing.
#   - \( \mu \) is the mean of the distribution.
#   - \( \sigma \) is the standard deviation of the distribution.
#
# - By converting data points into Z-scores, you remove the influence of the **original scale** (e.g., centimeters, dollars, etc.), which allows you to compare values across different distributions directly.
#
# ### **Using Z-Scores to Compare Different Distributions**:
# 1. **Comparing Data from Different Distributions**:
#    - **Different scales**: Suppose you have two distributions: one representing the heights of people (in centimeters) and another representing test scores (in points). The original units (height vs. score) make direct comparison difficult.
#    - When you convert each data point from both distributions to Z-scores, you transform them into **standardized scores**, representing how far they are from their respective means in terms of standard deviations.
#    - This allows for a **fair comparison**: For example, a Z-score of +2 in one distribution indicates the data point is 2 standard deviations above the mean, and a Z-score of +2 in another distribution also indicates the data point is 2 standard deviations above the mean, regardless of the original units.
#
# 2. **Comparing Different Distributions with Different Means and Standard Deviations**:
#    - Different distributions may have different means and standard deviations. A Z-score standardizes for these differences, making the comparison based solely on the **relative position** within each distribution, not the absolute values.
#    - For example:
#      - In one distribution (e.g., heights of people), the mean is 160 cm with a standard deviation of 10 cm.
#      - In another distribution (e.g., exam scores), the mean is 75 points with a standard deviation of 15 points.
#      - A score of 170 cm in the first distribution would correspond to a Z-score of \( Z = \frac{170 - 160}{10} = 1 \) (1 standard deviation above the mean).
#      - A score of 90 points in the second distribution would correspond to a Z-score of \( Z = \frac{90 - 75}{15} = 1 \) (also 1 standard deviation above the mean).
#    - Both values (170 cm in the first and 90 points in the second) have the same relative position to their respective means, so they can be directly compared using their Z-scores.
#
# 3. **Comparing Different Distributions with Different Shapes**:
#    - Z-scores are most useful when the distributions are **normal** or approximately normal. However, they can still help compare data from distributions with different shapes (skewed, bimodal, etc.), although caution is needed if the distributions are highly non-normal.
#    - For non-normal distributions, comparing Z-scores can still give insights into how extreme or unusual a data point is within its own distribution, even if the overall shape of the distribution is not symmetric.
#
# 4. **Real-World Example**:
#    - Imagine you want to compare the performance of two students:
#      - **Student A** scored 85 on a math test with a mean score of 70 and a standard deviation of 5.
#      - **Student B** scored 90 on a history test with a mean score of 75 and a standard deviation of 10.
#    - To compare their performances, convert each score to a Z-score:
#      - Student A's Z-score: \( Z_A = \frac{85 - 70}{5} = 3 \)
#      - Student B's Z-score: \( Z_B = \frac{90 - 75}{10} = 1.5 \)
#    - **Interpretation**: Student A’s score is 3 standard deviations above the mean, while Student B’s score is 1.5 standard deviations above the mean. Therefore, even though Student B scored higher, Student A performed relatively better compared to their peers.
#
# ##Q21)What are the assumptions for applying the Central Limit Theorem ?
#
# Ans:The **Central Limit Theorem (CLT)** is a fundamental concept in statistics that allows us to approximate the distribution of sample means as a normal distribution, even if the population distribution is not normal. However, there are certain **assumptions** that must be met for the CLT to apply effectively:
#
# ### **Assumptions for the Central Limit Theorem**:
#
# 1. **Random Sampling**:
#    - The data must be **randomly sampled** from the population. This ensures that each observation has an equal chance of being selected and that the sample is representative of the population.
#
# 2. **Independent Observations**:
#    - The observations in the sample must be **independent** of each other. This means that the value of one observation should not influence or depend on another. This assumption is crucial to avoid biases and ensure the validity of the CLT.
#
# 3. **Sample Size**:
#    - The sample size must be **sufficiently large**. While there is no strict cutoff, a general rule of thumb is that the sample size \( n \) should be at least **30** for the CLT to hold. For **small sample sizes** (less than 30), the population should be approximately **normally distributed** for the CLT to apply effectively.
#    - If the sample size is small and the population distribution is highly skewed or non-normal, the sample mean may not be approximately normal, and the CLT may not apply well.
#
# 4. **Finite Variance**:
#    - The population from which the samples are drawn must have a **finite variance**. This means the population should not have infinite variability or outliers that could skew the results.
#
# 5. **Sample Without Replacement (if applicable)**:
#    - If the sampling is **without replacement**, the population should be **large enough** relative to the sample size (typically, the sample size should not exceed 10% of the population size). This ensures that sampling without replacement does not affect the independence of observations too much.
#
# ##Q22)What is the concept of expected value in a probability distribution ?
#
# Ans:The **expected value** in a probability distribution is the **weighted average** of all possible outcomes, where each outcome is weighted by its probability. It represents the **long-term average** or **center** of the distribution, indicating what you would expect on average if an experiment were repeated many times.
#
# - For a discrete random variable, it's calculated as:
#   \[
#   E[X] = \sum x_i \cdot P(x_i)
#   \]
#
# - For a continuous random variable, it's calculated using an integral:
#   \[
#   E[X] = \int x \cdot f(x) \, dx
#   \]
#
# The expected value provides a measure of the **central tendency** of the distribution.
#
# ##Q23)How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans:A **probability distribution** describes all possible outcomes of a **random variable** and their associated probabilities. The **expected outcome** (or **expected value**) is a weighted average of these outcomes, where each outcome is weighted by its probability. It gives the **average value** you would expect over many trials of the random experiment. The expected value is directly calculated from the probability distribution.
#
#
# ###PRATICAL QUESTION###
#
# ##Q1)Write a Python program to generate a random variable and display its value ?
#
# Ans:

# %%
import random

# Generate a random variable between 1 and 100
random_value = random.randint(1, 100)

# Display the random value
print(f"The randomly generated value is: {random_value}")
# Out:
# The randomly generated value is: 50

# %% [markdown]
# ##Q2)Generate a discrete uniform distribution using Python and plot the probability mass function (PMF) ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range for the discrete uniform distribution
low, high = 1, 6  # For example, rolling a fair die (1 to 6)

# Generate a sample of random values from the discrete uniform distribution
samples = np.random.randint(low, high + 1, size=1000)  # 1000 samples

# Calculate the PMF (probability mass function)
values, counts = np.unique(samples, return_counts=True)
pmf = counts / len(samples)

# Plot the PMF
plt.figure(figsize=(8, 6))
plt.bar(values, pmf, color='blue', alpha=0.7)
plt.xlabel('Possible Outcomes')
plt.ylabel('Probability')
plt.title('Probability Mass Function (PMF) of a Discrete Uniform Distribution')
plt.xticks(values)
plt.show()

# %% [markdown]
# ##Q3)Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution ?
#
# Ans:

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the Probability Distribution Function (PDF) of a Bernoulli distribution.

    Parameters:
    x (int): The outcome (either 0 or 1).
    p (float): The probability of success (0 <= p <= 1).

    Returns:
    float: The probability of the outcome x.
    """
    if x not in [0, 1]:
        raise ValueError("x must be either 0 or 1")
    if p < 0 or p > 1:
        raise ValueError("p must be between 0 and 1")

    # PDF for Bernoulli distribution
    if x == 1:
        return p  # Probability of success
    else:
        return 1 - p  # Probability of failure

# Example usage:
p = 0.7  # Probability of success
x_0 = 0  # Outcome 0 (failure)
x_1 = 1  # Outcome 1 (success)

print(f"P(X = {x_0}) = {bernoulli_pdf(x_0, p)}")
print(f"P(X = {x_1}) = {bernoulli_pdf(x_1, p)}")
# Out:
# P(X = 0) = 0.30000000000000004
# P(X = 1) = 0.7

# %% [markdown]
# ##Q4)Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Binomial distribution
n = 10  # number of trials
p = 0.5  # probability of success

# Simulate a binomial distribution by generating 1000 random samples
samples = np.random.binomial(n, p, size=1000)

# Plot the histogram of the binomial distribution
plt.figure(figsize=(8, 6))
plt.hist(samples, bins=range(n+2), edgecolor='black', alpha=0.7, density=True)
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(range(n+1))
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q5)Create a Poisson distribution and visualize it using Python ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Poisson distribution
lambda_ = 5  # average rate (mean) of occurrence

# Generate 1000 random samples from the Poisson distribution
samples = np.random.poisson(lambda_, 1000)

# Plot the histogram of the Poisson distribution
plt.figure(figsize=(8, 6))
plt.hist(samples, bins=range(min(samples), max(samples) + 1), edgecolor='black', alpha=0.7, density=True)
plt.xlabel('Number of events')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={lambda_})')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q6)Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete  uniform distribution ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Discrete Uniform Distribution
low, high = 1, 6  # For example, a 6-sided die (1 to 6)

# Generate the possible outcomes (1, 2, 3, ..., 6)
outcomes = np.arange(low, high + 1)

# Calculate the probability of each outcome (uniform distribution)
probabilities = np.ones(len(outcomes)) / len(outcomes)

# Calculate the CDF: cumulative sum of probabilities
cdf = np.cumsum(probabilities)

# Plot the CDF
plt.figure(figsize=(8, 6))
plt.step(outcomes, cdf, where='post', label='CDF', color='blue', linewidth=2)
plt.xlabel('Possible Outcomes')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of a Discrete Uniform Distribution')
plt.xticks(outcomes)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q7)Generate a continuous uniform distribution using NumPy and visualize it ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Continuous Uniform Distribution
low = 0  # Lower bound of the distribution
high = 10  # Upper bound of the distribution
size = 10000  # Number of random samples

# Generate random samples from the continuous uniform distribution
samples = np.random.uniform(low, high, size)

# Plot the histogram of the continuous uniform distribution
plt.figure(figsize=(8, 6))
plt.hist(samples, bins=50, edgecolor='black', alpha=0.7, density=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Continuous Uniform Distribution (low={low}, high={high})')

# Add a line for the theoretical PDF (constant value across the range)
plt.axhline(y=1 / (high - low), color='r', linestyle='--', label=f'Theoretical PDF (1/({high-low}))')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ##Q8)Simulate data from a normal distribution and plot its histogram ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Normal Distribution
mean = 0      # Mean of the distribution
std_dev = 1   # Standard deviation of the distribution
size = 10000  # Number of samples to generate

# Generate random samples from a normal distribution
samples = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot the histogram of the normal distribution
plt.figure(figsize=(8, 6))
plt.hist(samples, bins=50, edgecolor='black', alpha=0.7, density=True)

# Add a line for the theoretical PDF of the normal distribution
from scipy.stats import norm
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std_dev)
plt.plot(x, p, 'k', linewidth=2, label='Theoretical PDF')

# Labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Histogram of Normal Distribution (mean={mean}, std_dev={std_dev})')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ##Q9)Write a Python function to calculate Z-scores from a dataset and plot them ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """
    Calculate the Z-scores for a given dataset.

    Parameters:
    data (array-like): Input dataset.

    Returns:
    array: Z-scores of the input dataset.
    """
    mean = np.mean(data)
    std_dev = np.std(data)

    # Calculate Z-scores for each data point
    z_scores = (data - mean) / std_dev

    return z_scores

def plot_z_scores(z_scores):
    """
    Plot the Z-scores as a histogram.

    Parameters:
    z_scores (array-like): Array of Z-scores.
    """
    plt.figure(figsize=(8, 6))
    plt.hist(z_scores, bins=30, edgecolor='black', alpha=0.7)
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.title('Histogram of Z-scores')
    plt.grid(True)
    plt.show()

# Example usage:
# Create a random dataset from a normal distribution
data = np.random.normal(loc=10, scale=2, size=1000)

# Calculate Z-scores for the dataset
z_scores = calculate_z_scores(data)

# Plot the Z-scores
plot_z_scores(z_scores)

# %% [markdown]
# ##Q10)Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

def central_limit_theorem(population_dist, sample_size, num_samples, dist_params):
    """
    Apply the Central Limit Theorem (CLT) by sampling from a non-normal population distribution.

    Parameters:
    - population_dist: The distribution function to sample from (e.g., np.random.exponential).
    - sample_size: The size of each sample drawn from the population.
    - num_samples: The number of samples to draw.
    - dist_params: Parameters for the population distribution (e.g., rate for exponential).

    Returns:
    - sample_means: List of means of each sample.
    """
    sample_means = []

    for _ in range(num_samples):
        sample = population_dist(*dist_params, size=sample_size)
        sample_means.append(np.mean(sample))

    return sample_means

# Parameters
population_dist = np.random.exponential  # Non-normal distribution (Exponential distribution)
dist_params = (1,)  # Rate (lambda) for the exponential distribution
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples to draw

# Apply Central Limit Theorem
sample_means = central_limit_theorem(population_dist, sample_size, num_samples, dist_params)

# Plot the distribution of sample means
plt.figure(figsize=(8, 6))
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)
plt.xlabel('Sample Means')
plt.ylabel('Density')
plt.title('Central Limit Theorem: Sample Means Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q15)Simulate multiple samples from a normal distribution and verify the Central Limit Theorem ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

def central_limit_theorem_normal(pop_mean, pop_std, sample_size, num_samples):
    """
    Apply the Central Limit Theorem by sampling from a normal population distribution.

    Parameters:
    - pop_mean: Mean of the normal distribution.
    - pop_std: Standard deviation of the normal distribution.
    - sample_size: The size of each sample drawn from the population.
    - num_samples: The number of samples to draw.

    Returns:
    - sample_means: List of means of each sample.
    """
    sample_means = []

    for _ in range(num_samples):
        sample = np.random.normal(pop_mean, pop_std, sample_size)  # Draw a sample
        sample_means.append(np.mean(sample))  # Calculate and store the sample mean

    return sample_means

# Parameters for the Normal Distribution
population_mean = 50  # Mean of the normal distribution
population_std_dev = 10  # Standard deviation of the normal distribution
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples to draw

# Apply Central Limit Theorem for a normal distribution
sample_means = central_limit_theorem_normal(population_mean, population_std_dev, sample_size, num_samples)

# Plot the distribution of sample means
plt.figure(figsize=(8, 6))
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)
plt.xlabel('Sample Means')
plt.ylabel('Density')
plt.title('Central Limit Theorem: Sample Means Distribution (Normal Population)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q16) Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_standard_normal_distribution():
    """
    Calculate and plot the standard normal distribution (mean=0, std=1).
    """
    # Generate values from -4 to 4 (this range captures most of the distribution)
    x = np.linspace(-4, 4, 1000)

    # Standard normal distribution PDF formula: f(x) = (1 / sqrt(2 * pi)) * exp(-x^2 / 2)
    y = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)

    # Plotting the standard normal distribution
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label="Standard Normal Distribution", color='b', linewidth=2)
    plt.fill_between(x, y, alpha=0.2, color='blue')

    # Adding labels and title
    plt.xlabel('X')
    plt.ylabel('Density')
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.grid(True)
    plt.legend()
    plt.show()

# Call the function to plot the standard normal distribution
plot_standard_normal_distribution()

# %% [markdown]
# ##Q17)Generate random variables and calculate their corresponding probabilities using the binomial distribution ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def binomial_distribution(n, p, size):
    """
    Generate random variables from a binomial distribution and calculate their probabilities.

    Parameters:
    - n: number of trials.
    - p: probability of success on each trial.
    - size: number of random variables to generate.

    Returns:
    - random_vars: array of random variables generated from the binomial distribution.
    - probabilities: array of corresponding probabilities for each random variable.
    """
    # Generate random variables from a binomial distribution
    random_vars = np.random.binomial(n, p, size)

    # Calculate the corresponding probabilities using the binomial PMF
    probabilities = binom.pmf(random_vars, n, p)

    return random_vars, probabilities

# Parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5  # Probability of success on each trial
size = 1000  # Number of random variables to generate

# Generate random variables and their probabilities
random_vars, probabilities = binomial_distribution(n, p, size)

# Plot the histogram of the random variables
plt.figure(figsize=(8, 6))
plt.hist(random_vars, bins=np.arange(-0.5, n+1.5, 1), density=True, edgecolor='black', alpha=0.7)

# Overlay the binomial probability mass function (PMF)
x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)
plt.plot(x, pmf_values, 'bo', label="Binomial PMF", markersize=8)

# Add labels and title
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF and Histogram')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##Q18)Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal  distribution.
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, mean, std_dev):
    """
    Calculate the Z-score for a given data point.

    Parameters:
    - data_point: The value to calculate the Z-score for.
    - mean: The mean of the dataset.
    - std_dev: The standard deviation of the dataset.

    Returns:
    - Z: The Z-score for the data point.
    """
    Z = (data_point - mean) / std_dev
    return Z

def plot_standard_normal_distribution(Z_score):
    """
    Plot the standard normal distribution (mean=0, std=1) and mark the Z-score.

    Parameters:
    - Z_score: The Z-score to plot on the distribution.
    """
    # Generate x values for the standard normal distribution
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)  # Standard normal distribution (mean=0, std=1)

    # Plot the standard normal distribution
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label="Standard Normal Distribution", color='blue', linewidth=2)

    # Mark the Z-score on the plot
    plt.axvline(x=Z_score, color='red', linestyle='--', label=f'Z-score = {Z_score:.2f}')

    # Add labels and title
    plt.title('Standard Normal Distribution with Z-score')
    plt.xlabel('Z')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example: Data set values and a data point
data_point = 75  # Given data point
mean = 70        # Mean of the dataset
std_dev = 5      # Standard deviation of the dataset

# Calculate the Z-score
Z_score = calculate_z_score(data_point, mean, std_dev)
print(f"The Z-score for data point {data_point} is: {Z_score:.2f}")

# Plot the standard normal distribution and the Z-score
plot_standard_normal_distribution(Z_score)
# Out:
# The Z-score for data point 75 is: 1.00

# %% [markdown]
# ##Q19) Implement hypothesis testing using Z-statistics for a sample dataset .
#
# Ans:

# %%
import numpy as np
import scipy.stats as stats

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    """
    Perform a Z-test for a sample dataset to test if the sample mean is significantly different from
    the population mean.

    Parameters:
    - sample_data: A list or numpy array of sample data.
    - population_mean: The mean of the population (null hypothesis value).
    - population_std: The population standard deviation.
    - alpha: Significance level (default 0.05).

    Returns:
    - z_statistic: The calculated Z-statistic.
    - p_value: The p-value for the test.
    - decision: The decision whether to reject the null hypothesis.
    """
    # Calculate sample mean and sample size
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Calculate the standard error of the mean (SEM)
    sem = population_std / np.sqrt(sample_size)

    # Calculate the Z-statistic
    z_statistic = (sample_mean - population_mean) / sem

    # Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

    # Compare the p-value with the significance level to make a decision
    if p_value < alpha:
        decision = "Reject the null hypothesis"
    else:
        decision = "Fail to reject the null hypothesis"

    return z_statistic, p_value, decision

# Example: Sample data
sample_data = np.array([52, 55, 49, 60, 48, 50, 58, 53, 51, 47])

# Population parameters
population_mean = 50
population_std = 10

# Perform Z-test
z_stat, p_val, decision = z_test(sample_data, population_mean, population_std)

# Print results
print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {p_val:.4f}")
print(f"Decision: {decision}")
# Out:
# Z-statistic: 0.73
# P-value: 0.4670
# Decision: Fail to reject the null hypothesis

# %% [markdown]
# ##Q20)Create a confidence interval for a dataset using Python and interpret the result ?
#
# Ans:

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(sample_data, confidence_level=0.95):
    """
    Calculate the confidence interval for a dataset.

    Parameters:
    - sample_data: A list or numpy array of sample data.
    - confidence_level: The confidence level for the interval (default 0.95).

    Returns:
    - confidence_interval: The calculated confidence interval (lower bound, upper bound).
    """
    # Sample size
    n = len(sample_data)

    # Sample mean and sample standard deviation
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # Using ddof=1 for sample standard deviation

    # Degrees of freedom
    df = n - 1

    # t-critical value for the given confidence level
    t_critical = stats.t.ppf((1 + confidence_level) / 2, df)

    # Standard error of the mean (SEM)
    sem = sample_std / np.sqrt(n)

    # Margin of error
    margin_of_error = t_critical * sem

    # Confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Example: Sample data
sample_data = np.array([52, 55, 49, 60, 48, 50, 58, 53, 51, 47])

# Calculate the confidence interval (95% confidence level)
lower, upper = confidence_interval(sample_data, confidence_level=0.95)

# Print the result
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval: (49.25, 55.35)

# %% [markdown]
# ##Q21)Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
#
# Ans:

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(sample_data, confidence_level=0.95):
    """
    Calculate the confidence interval for a dataset.

    Parameters:
    - sample_data: A list or numpy array of sample data.
    - confidence_level: The confidence level for the interval (default 0.95).

    Returns:
    - confidence_interval: The calculated confidence interval (lower bound, upper bound).
    """
    # Sample size
    n = len(sample_data)

    # Sample mean and sample standard deviation
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # Using ddof=1 for sample standard deviation

    # Degrees of freedom
    df = n - 1

    # t-critical value for the given confidence level
    t_critical = stats.t.ppf((1 + confidence_level) / 2, df)

    # Standard error of the mean (SEM)
    sem = sample_std / np.sqrt(n)

    # Margin of error
    margin_of_error = t_critical * sem

    # Confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Generate random data from a normal distribution
np.random.seed(42)  # For reproducibility
mean = 50            # True mean of the normal distribution
std_dev = 10         # Standard deviation of the normal distribution
sample_size = 30     # Number of data points in the sample

# Generate sample data from the normal distribution
sample_data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate the confidence interval (95% confidence level)
lower, upper = confidence_interval(sample_data, confidence_level=0.95)

# Print the result
print(f"Generated sample data: {sample_data[:10]}...")  # Show first 10 values for brevity
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# Generated sample data: [54.96714153 48.61735699 56.47688538 65.23029856 47.65846625 47.65863043
#  65.79212816 57.67434729 45.30525614 55.42560044]...
# 95% Confidence Interval: (44.76, 51.48)

# %% [markdown]
# ##Q22)Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_normal_pdf(mean, std_dev):
    """
    Function to plot the Probability Density Function (PDF) of a normal distribution.

    Parameters:
    - mean: Mean of the normal distribution.
    - std_dev: Standard deviation of the normal distribution.
    """
    # Generate a range of x values from mean - 4*std_dev to mean + 4*std_dev
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

    # Calculate the PDF of the normal distribution for each x value
    pdf = stats.norm.pdf(x, loc=mean, scale=std_dev)

    # Plot the PDF
    plt.figure(figsize=(8, 6))
    plt.plot(x, pdf, label=f'Normal Distribution (mean={mean}, std={std_dev})', color='blue')
    plt.title('Probability Density Function (PDF) of a Normal Distribution')
    plt.xlabel('x')
    plt.ylabel('PDF')
    plt.grid(True)
    plt.legend()
    plt.show()

# Parameters for the normal distribution
mean = 0
std_dev = 1

# Plot the PDF
plot_normal_pdf(mean, std_dev)

# %% [markdown]
# ##Q23)Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_poisson_cdf(lmbda, max_value):
    """
    Function to calculate and plot the Cumulative Distribution Function (CDF) of a Poisson distribution.

    Parameters:
    - lmbda: The rate parameter (mean number of occurrences).
    - max_value: The maximum value for which to calculate the CDF.
    """
    # Generate x values from 0 to max_value
    x = np.arange(0, max_value+1)

    # Calculate the CDF for the Poisson distribution
    cdf = stats.poisson.cdf(x, lmbda)

    # Plot the CDF
    plt.figure(figsize=(8, 6))
    plt.step(x, cdf, label=f'Poisson CDF (λ={lmbda})', where='post', color='green')
    plt.title('Cumulative Distribution Function (CDF) of a Poisson Distribution')
    plt.xlabel('k (Number of events)')
    plt.ylabel('CDF (P(X ≤ k))')
    plt.grid(True)
    plt.legend()
    plt.show()

# Parameters for the Poisson distribution
lmbda = 4  # average rate (mean) of occurrence
max_value = 15  # maximum value to calculate CDF for

# Plot the CDF for the Poisson distribution
plot_poisson_cdf(lmbda, max_value)

# %% [markdown]
# ##Q24)Simulate a random variable using a continuous uniform distribution and calculate its expected value.
#
# Ans:

# %%
import numpy as np

# Function to simulate random variable and calculate expected value
def simulate_uniform_distribution(a, b, size=1000):
    """
    Simulate a random variable using a continuous uniform distribution and calculate its expected value.

    Parameters:
    - a: The lower bound of the distribution.
    - b: The upper bound of the distribution.
    - size: The number of random variables to simulate (default is 1000).

    Returns:
    - expected_value: The expected value calculated from the theoretical formula.
    - sample_mean: The mean of the simulated sample.
    """
    # Generate random variables from the continuous uniform distribution
    sample_data = np.random.uniform(a, b, size)

    # Calculate the expected value using the formula for a uniform distribution
    expected_value = (a + b) / 2

    # Calculate the sample mean from the simulated data
    sample_mean = np.mean(sample_data)

    return expected_value, sample_mean

# Parameters for the uniform distribution
a = 2  # lower bound
b = 8  # upper bound

# Simulate the random variable and calculate expected value
expected_value, sample_mean = simulate_uniform_distribution(a, b)

# Print results
print(f"Expected value (theoretical): {expected_value}")
print(f"Sample mean (calculated from simulation): {sample_mean}")
# Out:
# Expected value (theoretical): 5.0
# Sample mean (calculated from simulation): 4.968287716389481

# %% [markdown]
# ##Q25)Write a Python program to compare the standard deviations of two datasets and visualize the difference.
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

def compare_standard_deviations(data1, data2):
    """
    Compare the standard deviations of two datasets and visualize the difference.

    Parameters:
    - data1: First dataset (numpy array or list).
    - data2: Second dataset (numpy array or list).
    """
    # Calculate the standard deviations of both datasets
    std_dev_1 = np.std(data1)
    std_dev_2 = np.std(data2)

    print(f"Standard Deviation of Dataset 1: {std_dev_1:.2f}")
    print(f"Standard Deviation of Dataset 2: {std_dev_2:.2f}")

    # Visualize the datasets using histograms
    plt.figure(figsize=(10, 6))

    # Plot histogram for Dataset 1
    plt.hist(data1, bins=15, alpha=0.5, label="Dataset 1", color="blue")

    # Plot histogram for Dataset 2
    plt.hist(data2, bins=15, alpha=0.5, label="Dataset 2", color="orange")

    plt.title("Comparison of Two Datasets")
    plt.xlabel("Data Values")
    plt.ylabel("Frequency")
    plt.legend(loc="upper right")
    plt.grid(True)
    plt.show()

# Generate two datasets with different standard deviations
np.random.seed(42)  # For reproducibility

# Dataset 1: Normal distribution with mean 50 and standard deviation 10
dataset1 = np.random.normal(loc=50, scale=10, size=1000)

# Dataset 2: Normal distribution with mean 50 and standard deviation 20
dataset2 = np.random.normal(loc=50, scale=20, size=1000)

# Compare the standard deviations of the two datasets and visualize
compare_standard_deviations(dataset1, dataset2)
# Out:
# Standard Deviation of Dataset 1: 9.79
# Standard Deviation of Dataset 2: 19.94

# %% [markdown]
# ##Q26)Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
#
# Ans:

# %%
import numpy as np

def calculate_range_and_iqr(data):
    """
    Calculate the range and interquartile range (IQR) of a given dataset.

    Parameters:
    - data: The dataset (numpy array or list).

    Returns:
    - range_value: The range of the dataset.
    - iqr: The interquartile range (IQR) of the dataset.
    """
    # Calculate the range (max - min)
    range_value = np.max(data) - np.min(data)

    # Calculate the interquartile range (IQR)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1

    return range_value, iqr

# Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
mean = 50
std_dev = 10
size = 1000

# Generate the dataset
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Calculate the range and IQR
range_value, iqr = calculate_range_and_iqr(data)

# Print results
print(f"Range of the dataset: {range_value:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {iqr:.2f}")
# Out:
# Range of the dataset: 70.94
# Interquartile Range (IQR) of the dataset: 12.96

# %% [markdown]
# ##Q27)Implement Z-score normalization on a dataset and visualize its transformation.
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    """
    Apply Z-score normalization to the given dataset.

    Parameters:
    - data: The dataset (numpy array or list).

    Returns:
    - normalized_data: The Z-score normalized dataset.
    """
    mean = np.mean(data)
    std_dev = np.std(data)

    # Apply Z-score formula
    normalized_data = (data - mean) / std_dev

    return normalized_data

# Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
mean = 50
std_dev = 10
size = 1000

# Generate the dataset
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Apply Z-score normalization
normalized_data = z_score_normalization(data)

# Plot the original data and the normalized data
plt.figure(figsize=(12, 6))

# Histogram of original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='blue', alpha=0.7)
plt.title("Original Data (Normal Distribution)")
plt.xlabel("Data Values")
plt.ylabel("Frequency")

# Histogram of normalized data
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='green', alpha=0.7)
plt.title("Z-score Normalized Data")
plt.xlabel("Normalized Data Values")
plt.ylabel("Frequency")

# Show the plots
plt.tight_layout()
plt.show()

# Print the mean and standard deviation of the normalized data
print(f"Mean of the normalized data: {np.mean(normalized_data):.2f}")
print(f"Standard deviation of the normalized data: {np.std(normalized_data):.2f}")
# Out:
# Mean of the normalized data: -0.00
# Standard deviation of the normalized data: 1.00

# %% [markdown]
# ##Q28)Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal  distribution.
#
# Ans:

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_and_kurtosis(data):
    """
    Calculate the skewness and kurtosis of a given dataset.

    Parameters:
    - data: The dataset (numpy array or list).

    Returns:
    - skew_value: The skewness of the dataset.
    - kurtosis_value: The kurtosis of the dataset.
    """
    # Calculate skewness
    skew_value = skew(data)

    # Calculate kurtosis (default is Fisher's kurtosis, where normal = 0)
    kurtosis_value = kurtosis(data)

    return skew_value, kurtosis_value

# Generate a dataset from a normal distribution
np.random.seed(42)  # For reproducibility
mean = 50
std_dev = 10
size = 1000

# Generate the dataset
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Calculate skewness and kurtosis
skew_value, kurtosis_value = calculate_skewness_and_kurtosis(data)

# Print results
print(f"Skewness of the dataset: {skew_value:.4f}")
print(f"Kurtosis of the dataset: {kurtosis_value:.4f}")
# Out:
# Skewness of the dataset: 0.1168
# Kurtosis of the dataset: 0.0662
