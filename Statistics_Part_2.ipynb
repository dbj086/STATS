# %% [markdown]
# <a href="https://colab.research.google.com/github/dbj086/STATS/blob/main/Statistics_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##THEORY QUESTION##
#
# ##Q1) What is hypothesis testing in statistics ?
#
# Ans: **Hypothesis testing** in statistics is a method used to make decisions or inferences about population parameters based on sample data. It involves testing an assumption (called a **hypothesis**) about a population parameter.
#
# ### Key Concepts in Hypothesis Testing:
#
# 1. **Null Hypothesis (H₀)**:
#    This is the default assumption or status quo. It usually states that there is **no effect**, **no difference**, or **no change**.
#
#    * Example: H₀: The average height of adult men is 70 inches.
#
# 2. **Alternative Hypothesis (H₁ or Ha)**:
#    This is what you aim to support; it represents a new claim or an effect.
#
#    * Example: Ha: The average height of adult men is **not** 70 inches.
#
# 3. **Test Statistic**:
#    A value calculated from the sample data that is used to decide whether to reject the null hypothesis.
#
#    * Common test statistics include *z*, *t*, *chi-square*, and *F*.
#
# 4. **Significance Level (α)**:
#    A threshold probability used to determine when to reject H₀. Common values are 0.05, 0.01, or 0.10.
#
#    * If the probability of observing the test statistic under H₀ is less than α, we reject H₀.
#
# 5. **p-value**:
#    The probability of getting a result at least as extreme as the one observed, assuming H₀ is true.
#
#    * If the p-value < α, we reject H₀.
#
# 6. **Conclusion**:
#    Based on the p-value and α:
#
#    * If p-value < α → **Reject H₀** (evidence supports Ha)
#    * If p-value ≥ α → **Fail to reject H₀** (not enough evidence to support Ha)
#
# ---
#
# ##Q2) What is the null hypothesis, and how does it differ from the alternative hypothesis ?
#
# Ans:Great question! Let's break it down clearly:
#
# ---
#
# ### **1. Null Hypothesis (H₀):**
#
# The **null hypothesis** is a statement of **no effect**, **no difference**, or **no relationship**. It represents the **status quo** or what we assume to be true unless we have strong evidence against it.
#
# * **Purpose**: It provides a baseline or default position that we test against.
# * **Example**:
#
#   * If you're testing a new drug:
#     **H₀**: The new drug has no effect on blood pressure.
#
# ---
#
# ### **2. Alternative Hypothesis (H₁ or Ha):**
#
# The **alternative hypothesis** is what you are trying to find evidence for. It suggests that there **is an effect**, **a difference**, or **a relationship**.
#
# * **Purpose**: It's the hypothesis you support if the data show that H₀ is unlikely.
# * **Example**:
#
#   * **Ha**: The new drug **does reduce** blood pressure.
#
# ---
#
# ### 🔍 **Key Differences:**
#
# | Feature              | Null Hypothesis (H₀)                | Alternative Hypothesis (H₁ or Ha) |
# | -------------------- | ----------------------------------- | --------------------------------- |
# | What it states       | No change or effect                 | Some change or effect             |
# | Assumed true until…  | Evidence suggests otherwise         | Supported if H₀ is rejected       |
# | Goal in testing      | Try to find evidence **against** it | Try to find evidence **for** it   |
# | Symbol               | H₀                                  | H₁ or Ha                          |
# | Example (coin fair?) | H₀: Coin is fair (P = 0.5)          | Ha: Coin is not fair (P ≠ 0.5)    |
#
# ---
#
# ##Q3) What is the significance level in hypothesis testing, and why is it important ?
#
# Ans:### What Is the **Significance Level** in Hypothesis Testing?
#
# The **significance level**, denoted by **α (alpha)**, is a threshold used to decide whether to reject the **null hypothesis (H₀)**. It represents the **probability of making a Type I error**, which is **rejecting H₀ when it is actually true**.
#
# ---
#
# ### 🔢 Common Values of α:
#
# * **0.05 (5%)** — Most commonly used
# * **0.01 (1%)** — Stricter (less likely to reject H₀ unless very strong evidence)
# * **0.10 (10%)** — More lenient (used in exploratory research)
#
# ---
#
# ### Why Is It Important?
#
# 1. **Controls the Risk of False Positives**:
#    α sets the **maximum risk** you're willing to accept of wrongly rejecting a true null hypothesis.
#
#    * Example: If α = 0.05, you're allowing a 5% chance of wrongly concluding an effect exists when it doesn't.
#
# 2. **Sets the Bar for Evidence**:
#    The **smaller** the α, the **stronger** the evidence needed (i.e., a smaller p-value) to reject H₀.
#
# 3. **Determines the Decision Rule**:
#
#    * If **p-value < α**, you **reject H₀**
#    * If **p-value ≥ α**, you **fail to reject H₀**
#
# ---
#
# ### 🧠 Example:
#
# Let’s say you’re testing a new fertilizer and want to know if it increases crop yield.
#
# * **H₀**: The new fertilizer has no effect.
# * **Ha**: The new fertilizer increases yield.
# * You choose **α = 0.05**.
# * After testing, you find a **p-value = 0.03**.
# * Since **0.03 < 0.05**, you **reject H₀** — there is statistically significant evidence that the fertilizer works.
#
# ---
#
# ##Q4)What does a P-value represent in hypothesis testing ?
#
# Ans:### What Is a **P-value** in Hypothesis Testing?
#
# The **p-value** (short for *probability value*) is a key result in hypothesis testing. It tells you **how likely your sample results would be if the null hypothesis (H₀) were true**.
#
# ---
#
# ### 🔍 In Simple Terms:
#
# > The p-value is the probability of getting a result **at least as extreme** as the one you observed, **assuming H₀ is true**.
#
# ---
#
# ### 📊 What Does the P-value Tell You?
#
# * **Small p-value (e.g., < 0.05)**:
#
#   * Your observed data is **unlikely** under the null hypothesis.
#   * You have **evidence to reject H₀** in favor of the alternative hypothesis (Ha).
#
# * **Large p-value (e.g., ≥ 0.05)**:
#
#   * Your observed data is **likely** under H₀.
#   * You **do not reject H₀**; there isn’t strong enough evidence for Ha.
#
# ---
#
# ### 🧠 Example:
#
# You’re testing whether a coin is fair.
#
# * **H₀**: The coin is fair (P = 0.5).
# * You flip the coin 100 times and get 70 heads.
# * A statistical test gives you a **p-value of 0.003**.
#
# #### Interpretation:
#
# * There’s only a **0.3% chance** you would see 70 or more heads **if the coin were fair**.
# * Since 0.003 < 0.05, you **reject H₀**. There’s strong evidence the coin is not fair.
#
# ---
#
# ### 🚦 How to Use the P-value:
#
# | **P-value** | **Conclusion (if α = 0.05)**                      |
# | ----------- | ------------------------------------------------- |
# | p ≤ 0.05    | Reject H₀ → statistically significant result      |
# | p > 0.05    | Fail to reject H₀ → not statistically significant |
#
# > **Important**: A small p-value does **not** prove H₀ is false or that Ha is true. It just means the data would be **very unusual** if H₀ were true.
#
# ---
#
# ##Q5)How do you interpret the P-value in hypothesis testing ?
#
# Ans: ### How to Interpret the **P-value** in Hypothesis Testing
#
# The **p-value** helps you decide whether the data provides enough evidence to reject the **null hypothesis (H₀)**. Here's how to interpret it clearly:
#
# ---
#
# ### ✅ **Step-by-Step Interpretation**
#
# 1. **Understand what the p-value means**:
#    It is the **probability** of observing your sample results, or something more extreme, **assuming H₀ is true**.
#
# 2. **Compare it to the significance level (α)**:
#    Typically, α = 0.05 (5%).
#
# ---
#
# ### 🔍 **Interpretation Rules**
#
# | **P-value** | **Interpretation**                                                     |
# | ----------- | ---------------------------------------------------------------------- |
# | **p ≤ α**   | **Reject H₀**. There is **statistically significant evidence** for Ha. |
# | **p > α**   | **Fail to reject H₀**. There is **not enough evidence** to support Ha. |
#
# ---
#
# ### 🧠 **Example Interpretation**
#
# #### Example 1:
#
# * **Context**: Testing a new drug vs. a placebo
# * **H₀**: The drug has no effect.
# * **Ha**: The drug has an effect.
# * **Result**: p-value = 0.02, α = 0.05
#
# > **Interpretation**:
# > Since 0.02 < 0.05, **reject H₀**.
# > There is **statistically significant evidence** that the drug has an effect.
#
# ---
#
# #### Example 2:
#
# * **Same test**, but p-value = 0.08
#
# > **Interpretation**:
# > Since 0.08 > 0.05, **fail to reject H₀**.
# > There is **not enough evidence** to say the drug has an effect.
#
# ---
#
# ### ⚠️ Important Notes
#
# * A **small p-value** suggests the observed data is **unlikely under H₀**, leading you to **consider Ha instead**.
# * A **large p-value** means the data is **plausible under H₀**, so you **do not have strong enough evidence** to reject it.
# * **The p-value does not tell you**:
#
#   * The probability that H₀ is true
#   * The size or importance of the effect
#
# ---
#
# ##Q6)What are Type 1 and Type 2 errors in hypothesis testing ?
#
# Ans:Great question! Understanding **Type I and Type II errors** is essential in hypothesis testing because they explain the risks involved in making decisions based on data.
#
# ---
#
# ### ✅ **Overview of Hypothesis Testing Outcomes**
#
# In hypothesis testing, there are two possible decisions:
#
# * **Reject the null hypothesis (H₀)**
# * **Fail to reject the null hypothesis (H₀)**
#
# And there are two realities:
#
# * **H₀ is actually true**
# * **H₀ is actually false**
#
# Combining these gives **four possible outcomes**:
#
# | **Decision**          | **H₀ True**           | **H₀ False**                |
# | --------------------- | --------------------- | --------------------------- |
# | **Reject H₀**         | ❌ **Type I Error**    | ✅ Correct (Detected Effect) |
# | **Fail to Reject H₀** | ✅ Correct (No Effect) | ❌ **Type II Error**         |
#
# ---
#
# ### 🔴 **Type I Error (False Positive)**
#
# * **Definition**: Rejecting H₀ when it is actually true.
# * **You falsely conclude** there is an effect or difference.
# * **Probability** of Type I Error = **α (significance level)**
#
#   * Common α values: 0.05, 0.01
#
# > **Example**: You conclude a drug works when it actually doesn’t.
#
# ---
#
# ### 🔵 **Type II Error (False Negative)**
#
# * **Definition**: Failing to reject H₀ when it is actually false.
# * **You miss a real effect** that does exist.
# * **Probability** of Type II Error = **β**
#
#   * Related to **power = 1 − β**, the ability to detect a real effect.
#
# > **Example**: You conclude a drug doesn't work when it actually does.
#
# ---
#
# ### 🎯 **Balancing the Errors**
#
# * Lowering α reduces the chance of a **Type I error** but increases the risk of a **Type II error**.
# * Increasing the **sample size** can reduce both errors.
#
# ---
#
# ### 🔁 Real-World Analogy: Courtroom
#
# | Legal Decision | Reality: Innocent    | Reality: Guilty            |
# | -------------- | -------------------- | -------------------------- |
# | **Convict**    | ❌ Type I Error       | ✅ Correct (justice served) |
# | **Let go**     | ✅ Correct (innocent) | ❌ Type II Error            |
#
# > Convicting an innocent = Type I
# > Letting a criminal go free = Type II
#
# ---
#
# ##Q7)What is the difference between a one-tailed and a two-tailed test in hypothesis testing ?
#
# Ans:Great question! The choice between a **one-tailed** and a **two-tailed** test in hypothesis testing depends on what you're trying to prove with your data. Here's a clear breakdown:
#
# ---
#
# ### ✅ **Key Difference**
#
# | Feature                 | **One-Tailed Test**                               | **Two-Tailed Test**                    |
# | ----------------------- | ------------------------------------------------- | -------------------------------------- |
# | **Tests for**           | An effect in **one specific direction**           | An effect in **either direction**      |
# | **Hypotheses**          | H₀: μ = μ₀<br>Ha: μ > μ₀ *or* μ < μ₀              | H₀: μ = μ₀<br>Ha: μ ≠ μ₀               |
# | **Critical region**     | Only in **one tail** of the distribution          | Split between **both tails**           |
# | **Use case**            | When you care about **only increase or decrease** | When you care about **any difference** |
# | **P-value compared to** | α (entire α in one tail)                          | α/2 in each tail                       |
#
# ---
#
# ### 📊 **Two-Tailed Test Example**
#
# You want to test if a machine fills soda bottles with **exactly** 500 ml.
#
# * **H₀**: μ = 500 ml
#
# * **Ha**: μ ≠ 500 ml
#
# * This is **two-tailed**, because you're concerned with either **too much or too little**.
#
# * Critical region: Both ends (e.g., < 490 or > 510 ml)
#
# ---
#
# ### 🔽 **One-Tailed Test Example**
#
# You want to test if a new training method **improves** test scores.
#
# * **H₀**: μ = 70
#
# * **Ha**: μ > 70
#
# * This is **one-tailed**, because you only care if the score **increased**.
#
# * Critical region: Only the upper tail of the distribution.
#
# ---
#
# ### 🎯 When to Use:
#
# | **Use a One-Tailed Test When...**                                                                |
# | ------------------------------------------------------------------------------------------------ |
# | You're only interested in detecting a **specific direction** of change (e.g., improvement only). |
# | A result in the **opposite direction** would not affect your conclusion.                         |
#
# | **Use a Two-Tailed Test When...**                                                |
# | -------------------------------------------------------------------------------- |
# | You're interested in **any difference**, whether it's an increase or a decrease. |
# | You want a more **conservative** and **balanced** test.                          |
#
# ---
#
# ### ⚠️ Important Note:
#
# You **must choose** between one-tailed and two-tailed **before** analyzing the data. Switching afterward is considered **statistically invalid** (and can bias results).
#
# ---
#
# ##Q8) What is the Z-test, and when is it used in hypothesis testing ?
#
# Ans: ### ✅ What is a **Z-test**?
#
# The **Z-test** is a type of **statistical hypothesis test** used to determine whether there is a significant difference between a sample statistic and a known population parameter — **when the population variance is known** (or the sample size is large).
#
# It uses the **Z-distribution** (standard normal distribution), which has a mean of 0 and a standard deviation of 1.
#
# ---
#
# ### 🔍 When is the Z-test Used?
#
# Use a **Z-test** when **ALL** the following conditions are met:
#
# | Condition                                                                                           | Explanation                                            |
# | --------------------------------------------------------------------------------------------------- | ------------------------------------------------------ |
# | ✅ The sample size is **large**                                                                      | Typically **n ≥ 30**                                   |
# | ✅ The population **standard deviation (σ)** is known                                                | Unlike the **t-test**, which is used when σ is unknown |
# | ✅ Data is **normally distributed** (or sample size large enough for Central Limit Theorem to apply) | Ensures valid Z-test results                           |
#
# ---
#
# ### 🧪 Types of Z-tests:
#
# 1. **One-Sample Z-test**:
#    Tests whether the sample mean differs from a known population mean.
#
#    * Example: Is the average SAT score of a class different from the national average of 1050?
#
# 2. **Two-Sample Z-test**:
#    Compares the means of two independent groups.
#
#    * Example: Is there a difference in average test scores between two schools?
#
# 3. **Z-test for Proportions**:
#    Tests if a sample proportion differs from a population proportion (or between two proportions).
#
#    * Example: Is the proportion of voters supporting a candidate different from 50%?
#
# ---
#
# ### 📐 Z-test Formula (One-Sample Mean):
#
# $$
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $\mu$ = population mean
# * $\sigma$ = population standard deviation
# * $n$ = sample size
#
# ---
#
# ### 🎯 Example:
#
# Suppose:
#
# * Population mean (μ) = 100
# * Population standard deviation (σ) = 15
# * Sample mean (𝑋̄) = 108
# * Sample size (n) = 36
#
# $$
# Z = \frac{108 - 100}{15 / \sqrt{36}} = \frac{8}{2.5} = 3.2
# $$
#
# A Z-score of 3.2 is far in the tail — leading to a very low p-value → **Reject H₀**.
#
# ---
#
# ##Q9)How do you calculate the Z-score, and what does it represent in hypothesis testing ?
#
# Ans: ### ✅ What Is a **Z-score** in Hypothesis Testing?
#
# The **Z-score** (or **Z-statistic**) measures how many **standard deviations** a sample statistic (like the sample mean) is from the **population mean**, under the assumption that the null hypothesis (H₀) is true.
#
# ---
#
# ### 📐 **Z-score Formula for a Sample Mean**:
#
# $$
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $\mu$ = population mean (from H₀)
# * $\sigma$ = population standard deviation
# * $n$ = sample size
#
# ---
#
# ### 📊 What Does the Z-score Represent?
#
# * It tells you how **far** your sample mean is from the hypothesized population mean, **in units of standard error**.
# * The Z-score is used to find the **p-value**, which helps decide whether to **reject** or **fail to reject** the null hypothesis.
#
# ---
#
# ### 🔍 **Interpreting the Z-score**:
#
# | **Z-score** | **Interpretation**                                       |
# | ----------- | -------------------------------------------------------- |
# | Around 0    | Sample mean is close to population mean (H₀ likely true) |
# | ±1.96       | Critical value at α = 0.05 for a two-tailed test         |
# | > ±2 or ±3  | Sample mean is far from H₀ — evidence **against H₀**     |
#
# ---
#
# ### 🧠 Example:
#
# You want to test whether a machine fills bottles with exactly **500 ml** on average.
#
# * H₀: μ = 500 ml
# * Sample mean: $\bar{X} = 508$ ml
# * Population σ = 10 ml
# * Sample size n = 36
#
# $$
# Z = \frac{508 - 500}{10 / \sqrt{36}} = \frac{8}{10 / 6} = \frac{8}{1.67} \approx 4.8
# $$
#
# * **Z = 4.8** → This is far in the tail of the standard normal curve.
# * Corresponding **p-value** is near **0**, so you **reject H₀**.
#
# ---
#
# ##Q10) What is the T-distribution, and when should it be used instead of the normal distribution ?
#
# Ans: ### ✅ What Is the **T-distribution**?
#
# The **T-distribution** (also called **Student's t-distribution**) is a probability distribution that is similar in shape to the **normal distribution**, but with **heavier tails**. It accounts for the **extra uncertainty** that arises when the **population standard deviation (σ)** is **unknown** and must be **estimated from the sample**.
#
# ---
#
# ### 📈 Key Features of the T-distribution:
#
# | Feature                            | Description                                                    |
# | ---------------------------------- | -------------------------------------------------------------- |
# | Shape                              | Symmetrical and bell-shaped like the normal distribution       |
# | Tails                              | **Thicker** than the normal distribution (more extreme values) |
# | Center                             | Mean = 0                                                       |
# | Depends on Degrees of Freedom (df) | df = n − 1 (for one sample)                                    |
# | Approaches Normal Curve            | As sample size increases (n → ∞), it becomes normal            |
#
# ---
#
# ### 🧪 When to Use the T-distribution Instead of the Normal (Z) Distribution:
#
# | Use **T-distribution** when...                             |
# | ---------------------------------------------------------- |
# | ✅ The **population standard deviation (σ)** is **unknown** |
# | ✅ The **sample size is small** (typically n < 30)          |
# | ✅ Data is **approximately normal** or sample is random     |
#
# > **If σ is known** and sample size is large → use the **Z-distribution**
# > **If σ is unknown** → use the **T-distribution**
#
# ---
#
# ### 📐 Formula for the T-statistic (One-Sample Test):
#
# $$
# t = \frac{\bar{X} - \mu}{s / \sqrt{n}}
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $\mu$ = population mean under H₀
# * $s$ = sample standard deviation (estimate of σ)
# * $n$ = sample size
# * $df = n - 1$
#
# ---
#
# ### 🧠 Example:
#
# * You're testing if a class's average test score differs from 75.
# * Sample mean $\bar{X} = 78$
# * Sample standard deviation $s = 10$
# * Sample size $n = 16$
#
# $$
# t = \frac{78 - 75}{10 / \sqrt{16}} = \frac{3}{2.5} = 1.2
# $$
#
# * Degrees of freedom = 15
# * Look up critical value or p-value from the **t-table** to interpret the result.
#
# ---
#
# ##Q11)What is the difference between a Z-test and a T-test ?
#
# Ans:Great question! Here’s a clear comparison between the **Z-test** and the **T-test**, highlighting when and how each is used:
#
# ---
#
# ### **Z-test vs. T-test: Key Differences**
#
# | Feature                | **Z-test**                                    | **T-test**                                               |
# | ---------------------- | --------------------------------------------- | -------------------------------------------------------- |
# | **Population SD (σ)**  | Known                                         | Unknown                                                  |
# | **Sample Size (n)**    | Large (typically n ≥ 30)                      | Small or large (especially small, n < 30)                |
# | **Distribution Used**  | Standard Normal (Z-distribution)              | Student’s t-distribution (depends on degrees of freedom) |
# | **Test Statistic**     | $Z = \frac{\bar{X} - \mu}{\sigma/\sqrt{n}}$   | $t = \frac{\bar{X} - \mu}{s/\sqrt{n}}$                   |
# | **Standard Deviation** | Population standard deviation σ               | Sample standard deviation $s$ (estimate of σ)            |
# | **Tail Behavior**      | Thinner tails                                 | Heavier tails, accounts for more variability             |
# | **When to Use**        | When σ is known and/or sample size is large   | When σ is unknown, especially for small sample sizes     |
# | **Examples**           | Quality control in manufacturing with known σ | Small clinical trials or experiments with unknown σ      |
#
# ---
#
# ### **Summary:**
#
# * Use a **Z-test** when:
#
#   * The population standard deviation $\sigma$ is **known**.
#   * The sample size is **large** (≥ 30), so the sample standard deviation approximates the population SD.
# * Use a **T-test** when:
#
#   * The population standard deviation $\sigma$ is **unknown**.
#   * The sample size is **small** (typically less than 30).
#   * The sample data is approximately normally distributed.
#
# ---
#
# ### 🧠 Intuition Behind the Difference:
#
# Because the **T-test** uses the sample standard deviation $s$ to estimate the unknown population standard deviation, there is extra uncertainty. The **T-distribution** accounts for this by having heavier tails, meaning you need more evidence to reject the null hypothesis for small samples.
#
# ---
#
#
#
# ##Q12)What is the T-test, and how is it used in hypothesis testing ?
#
# Ans:### What Is a **T-test**?
#
# A **T-test** is a statistical method used to determine if there is a significant difference between:
#
# * The mean of a sample and a known value (usually the population mean), or
# * The means of two groups (independent or paired samples),
#
# when the **population standard deviation (σ) is unknown** and the sample size is relatively **small**.
#
# ---
#
# ### Why Use a T-test?
#
# * When **σ is unknown**, you estimate variability using the **sample standard deviation (s)**.
# * The T-test accounts for this uncertainty using the **T-distribution**, which has heavier tails than the normal distribution.
# * This helps avoid overestimating significance when the sample is small.
#
# ---
#
# ### Common Types of T-tests
#
# | Test Type                         | Use Case                                                               |
# | --------------------------------- | ---------------------------------------------------------------------- |
# | **One-Sample T-test**             | Compare sample mean to a known population mean.                        |
# | **Independent Two-Sample T-test** | Compare means of two independent groups (e.g., drug vs. placebo).      |
# | **Paired Sample T-test**          | Compare means from the same group at two time points or matched pairs. |
#
# ---
#
# ### How the T-test Works (One-Sample Example)
#
# 1. **Set hypotheses:**
#
# $$
# H_0: \mu = \mu_0 \quad \text{(no difference)}
# $$
#
# $$
# H_a: \mu \neq \mu_0 \quad \text{(two-tailed)}
# $$
#
# 2. **Calculate the T-statistic:**
#
# $$
# t = \frac{\bar{X} - \mu_0}{s / \sqrt{n}}
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $\mu_0$ = population mean under H₀
# * $s$ = sample standard deviation
# * $n$ = sample size
#
# 3. **Determine degrees of freedom (df):**
#
# $$
# df = n - 1
# $$
#
# 4. **Find the critical t-value or p-value** from the t-distribution table using $df$.
#
# 5. **Make a decision:**
#
# * If $|t| > \text{critical value}$ or p-value < significance level (α), **reject H₀**.
# * Otherwise, **fail to reject H₀**.
#
# ---
#
# ### Example:
#
# * Sample size $n = 20$
# * Sample mean $\bar{X} = 105$
# * Population mean $\mu_0 = 100$
# * Sample standard deviation $s = 15$
# * Significance level $\alpha = 0.05$
#
# Calculate:
#
# $$
# t = \frac{105 - 100}{15 / \sqrt{20}} = \frac{5}{3.35} \approx 1.49
# $$
#
# Degrees of freedom = 19.
#
# Check the t-table for $df = 19$ at α=0.05 (two-tailed), critical value ≈ 2.093.
#
# Since $1.49 < 2.093$, **fail to reject H₀** — no significant difference.
#
# ---
#
# ##Q13)  What is the relationship between Z-test and T-test in hypothesis testing ?
#
# Ans:Great question! The **Z-test** and **T-test** are closely related statistical methods used for hypothesis testing, but they differ based on what information you have and the sample size.
#
# ---
#
# ### **Relationship Between Z-test and T-test**
#
# | Aspect                      | Z-test                                                                          | T-test                                                  |
# | --------------------------- | ------------------------------------------------------------------------------- | ------------------------------------------------------- |
# | **Population SD (σ)**       | Known                                                                           | Unknown — estimated by sample SD (s)                    |
# | **Sample Size**             | Large (typically n ≥ 30)                                                        | Small or large, but especially useful when n < 30       |
# | **Underlying Distribution** | Uses **normal distribution** (Z-distribution)                                   | Uses **Student’s t-distribution** (heavier tails)       |
# | **Test Statistic Formula**  | $Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}$                                   | $t = \frac{\bar{X} - \mu}{s / \sqrt{n}}$                |
# | **Degrees of Freedom**      | Not applicable (normal dist. fixed)                                             | Depends on sample size (df = n − 1 for one sample test) |
# | **When Tends to Converge**  | As sample size increases, the t-distribution approaches the normal distribution |                                                         |
#
# ---
#
# ### Intuition Behind the Relationship:
#
# * When **σ is known** and/or the **sample size is large**, the **Z-test** is appropriate because the sample mean’s distribution is well approximated by a normal distribution.
# * When **σ is unknown** and the **sample size is small**, the **T-test** is better because it accounts for the added uncertainty in estimating σ using the sample standard deviation. The heavier tails of the t-distribution reflect this uncertainty.
# * As the **sample size grows larger**, the **t-distribution approaches the normal distribution**, making the **T-test and Z-test results nearly the same**.
#
# ---
#
# ##Q14) What is a confidence interval, and how is it used to interpret statistical results ?
#
# Ans: ### What Is a **Confidence Interval (CI)**?
#
# A **confidence interval** is a **range of values** calculated from sample data that is likely to contain the **true population parameter** (like the population mean) with a specified level of confidence.
#
# ---
#
# ### Key Points:
#
# * It gives an **estimate range** rather than a single point estimate.
# * The confidence level (e.g., 95%) tells us how confident we are that the interval contains the true parameter.
# * It reflects the **uncertainty** due to sampling variability.
#
# ---
#
# ### Example:
#
# A **95% confidence interval** means:
#
# > If you took many samples and calculated a confidence interval from each, **about 95% of those intervals would contain the true population parameter**.
#
# ---
#
# ### How to Calculate a Confidence Interval for a Mean:
#
# $$
# \text{CI} = \bar{X} \pm (\text{critical value}) \times \frac{s}{\sqrt{n}}
# $$
#
# Where:
#
# * $\bar{X}$ = sample mean
# * $s$ = sample standard deviation (or population SD if known)
# * $n$ = sample size
# * **Critical value** = depends on confidence level and distribution (Z for large samples or known σ, t for small samples and unknown σ)
#
# ---
#
# ### Example:
#
# * Sample mean $\bar{X} = 100$
# * Sample standard deviation $s = 15$
# * Sample size $n = 25$
# * Confidence level = 95%
# * Degrees of freedom = 24
# * Critical t-value ≈ 2.064
#
# Calculate margin of error:
#
# $$
# ME = 2.064 \times \frac{15}{\sqrt{25}} = 2.064 \times 3 = 6.192
# $$
#
# So, the 95% CI is:
#
# $$
# 100 \pm 6.192 = (93.81, 106.19)
# $$
#
# ---
#
# ### How Is It Used in Interpreting Results?
#
# * **If the CI for a mean difference includes 0**, it suggests **no significant difference** at the chosen confidence level.
# * **If the CI does NOT include the null hypothesis value**, it supports **rejecting the null hypothesis**.
# * Gives a **range of plausible values** for the population parameter, helping understand precision.
#
# ---
#
# ### Why Confidence Intervals Are Useful:
#
# * They provide more information than just a p-value.
# * They show **both the estimate and the uncertainty**.
# * Help assess the **practical significance** of results.
#
# ---
#
# ##Q15) What is the margin of error, and how does it affect the confidence interval ?
#
# ANS:The **margin of error** and the **confidence interval** are closely related statistical concepts used when estimating a population parameter (like a mean or proportion) based on a sample.
#
# ---
#
# ### 🔹 **What is the Margin of Error?**
#
# The **margin of error (MoE)** is a value that shows the range within which the true population parameter is likely to fall, given a certain level of confidence.
#
# It accounts for the variability in sampling and is usually expressed as:
#
# $$
# \text{Margin of Error} = z^* \times \text{Standard Error (SE)}
# $$
#
# Where:
#
# * $z^*$ is the **critical value** from the standard normal distribution (based on the chosen confidence level),
# * **Standard Error (SE)** measures the spread of the sampling distribution.
#
# ---
#
# ### 🔹 **How It Affects the Confidence Interval**
#
# The **confidence interval (CI)** gives a range of values believed to contain the true population parameter. It is calculated as:
#
# $$
# \text{Confidence Interval} = \text{Sample Estimate} \pm \text{Margin of Error}
# $$
#
# So, the **margin of error determines the width** of the confidence interval:
#
# * **Larger MoE → Wider CI** (more uncertainty)
# * **Smaller MoE → Narrower CI** (more precision)
#
# ---
#
# ### 🔹 Example
#
# Suppose you're estimating the average height of adult males in a city:
#
# * Sample mean = 70 inches
# * Margin of error = 2 inches
# * Confidence level = 95%
#
# Then your confidence interval is:
#
# $$
# 70 \pm 2 \rightarrow [68, 72] \text{ inches}
# $$
#
# You can say: *“We are 95% confident that the true average height is between 68 and 72 inches.”*
#
# ---
#
# ### 🔹 What Affects the Margin of Error?
#
# * **Sample Size (n):** Larger sample → smaller SE → smaller MoE
# * **Confidence Level:** Higher confidence (e.g., 99% vs 95%) → larger $z^*$ → larger MoE
# * **Population variability:** More variability → larger SE → larger MoE
#
# ---
#
# ##Q16) How is Bayes' Theorem used in statistics, and what is its significance ?
#
# ANS: **Bayes' Theorem** is a fundamental concept in statistics and probability that describes how to update the probability of a hypothesis based on new evidence. It plays a critical role in **Bayesian statistics**, where probabilities represent degrees of belief or uncertainty.
#
# ---
#
# ### 🔹 **What is Bayes’ Theorem?**
#
# Bayes’ Theorem is stated mathematically as:
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# Where:
#
# * $P(A|B)$ is the **posterior probability**: the probability of hypothesis $A$ given observed data $B$
# * $P(B|A)$ is the **likelihood**: the probability of observing data $B$ given that hypothesis $A$ is true
# * $P(A)$ is the **prior probability**: your belief in hypothesis $A$ before seeing the data
# * $P(B)$ is the **marginal probability**: the total probability of observing the data under all hypotheses
#
# ---
#
# ### 🔹 **How It’s Used in Statistics**
#
# #### ✅ 1. **Updating Beliefs**
#
# Bayes’ Theorem allows you to revise probabilities as more data becomes available. This is the core idea of **Bayesian inference**.
#
# #### ✅ 2. **Parameter Estimation**
#
# In Bayesian statistics, unknown parameters are treated as random variables. Bayes’ Theorem is used to compute their **posterior distributions**.
#
# #### ✅ 3. **Model Comparison**
#
# Bayesian methods can compare models using **Bayes factors**, which assess how well each model explains the observed data.
#
# #### ✅ 4. **Classification and Machine Learning**
#
# Used in algorithms like the **Naive Bayes classifier**, which applies Bayes’ Theorem under independence assumptions to classify data efficiently.
#
# ---
#
# ### 🔹 **Why It’s Significant**
#
# | Feature                          | Significance                                                              |
# | -------------------------------- | ------------------------------------------------------------------------- |
# | **Intuitive Updating**           | Mimics rational thinking: adjust your beliefs as new data comes in        |
# | **Incorporates Prior Knowledge** | Allows experts to include prior experience or historical data             |
# | **Probabilistic Interpretation** | Gives full probability distributions, not just point estimates            |
# | **Flexibility**                  | Can be used in complex models where frequentist methods are hard to apply |
#
# ---
#
# ##Q17)  What is the Chi-square distribution, and when is it used ?
#
# ANS: The **Chi-square distribution** is a probability distribution used primarily for testing hypotheses about **categorical data**. It is the distribution of the sum of squared standard normal variables and is only defined for non-negative values.
#
# ### **Used When:**
#
# * Testing **independence** between two categorical variables (Chi-square test of independence)
# * Testing **goodness of fit** to a theoretical distribution
# * Comparing **distributions across groups** (homogeneity test)
# * Constructing **confidence intervals** for a population variance (for normally distributed data)
#
# It's a key tool in inferential statistics for analyzing **frequency data**.
#
#
# ##Q18) What is the Chi-square goodness of fit test, and how is it applied ?
#
# ANS: The **Chi-square goodness of fit test** checks whether observed categorical data matches an expected distribution.
#
# ### **How It’s Applied:**
#
# 1. **State hypotheses**:
#
#    * Null (H₀): Observed data fits the expected distribution.
#    * Alternative (H₁): Observed data does not fit.
#
# 2. **Calculate expected frequencies** based on the hypothesized distribution.
#
# 3. **Compute test statistic**:
#
#    $$
#    \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
#    $$
#
#    where $O_i$ = observed frequency, $E_i$ = expected frequency.
#
# 4. **Compare** the statistic to the critical value from the Chi-square distribution (based on degrees of freedom and significance level).
#
# 5. **Make a decision**: If the statistic exceeds the critical value, reject H₀.
#
# ### **Used For**: Testing if a die is fair, if survey responses follow a known distribution, etc.
#
#
# ##Q19) What is the F-distribution, and when is it used in hypothesis testing ?
#
# ANS: The **F-distribution** is a probability distribution used to compare **two variances**. It is formed by the ratio of two scaled chi-square distributions.
#
# ### **Used In Hypothesis Testing:**
#
# 1. **ANOVA (Analysis of Variance)** – to test if **three or more group means** are significantly different.
# 2. **Variance comparison tests** – to test if **two population variances** are equal.
#
# ### **Key Points:**
#
# * Always **right-skewed**.
# * Depends on two **degrees of freedom** (one for each sample).
# * Used when dealing with **ratio of variances**.
#
# ##Q20)What is an ANOVA test, and what are its assumptions ?
#
# ANS: ### **What is an ANOVA Test?**
#
# **ANOVA (Analysis of Variance)** is a statistical test used to determine whether there are **significant differences between the means of three or more independent groups**.
#
# * **Null hypothesis (H₀):** All group means are equal.
# * **Alternative hypothesis (H₁):** At least one group mean is different.
#
# It uses the **F-distribution** to compare **between-group variance** to **within-group variance**.
#
# ---
#
# ### **Assumptions of ANOVA:**
#
# 1. **Independence**: Observations are independent within and between groups.
# 2. **Normality**: The data in each group are approximately normally distributed.
# 3. **Homogeneity of variance**: All groups have equal population variances.
#
# ---
#
# ##Q21)What are the different types of ANOVA tests ?
#
# ANS:There are **three main types of ANOVA tests**, each used based on the study design and number of factors involved:
#
# ---
#
# ### 🔹 **1. One-Way ANOVA**
#
# * **Purpose**: Tests differences between the means of **three or more groups** based on **one independent variable** (factor).
# * **Example**: Comparing exam scores across different teaching methods.
#
# ---
#
# ### 🔹 **2. Two-Way ANOVA**
#
# * **Purpose**: Tests the effect of **two independent variables** on a dependent variable and also checks for **interaction** between the two factors.
# * **Example**: Studying how both **teaching method** and **gender** affect test scores.
#
# ---
#
# ### 🔹 **3. Repeated Measures ANOVA**
#
# * **Purpose**: Used when the **same subjects** are measured under **multiple conditions or time points**.
# * **Example**: Measuring heart rate of participants **before, during, and after** exercise.
#
# ---
#
# ##Q22)What is the F-test, and how does it relate to hypothesis testing?
#
# ANS: ### **What is the F-test?**
#
# The **F-test** is a statistical test that compares **two variances** or evaluates **multiple group means** using the **F-distribution**.
#
# ---
#
# ### **How It Relates to Hypothesis Testing:**
#
# The F-test is used to test whether:
#
# * **Two population variances are equal** (variance comparison)
# * **Group means differ** (in **ANOVA**)
#
# It does this by calculating the **F-statistic**, which is the ratio of two variances:
#
# $$
# F = \frac{\text{Variance between groups}}{\text{Variance within groups}}
# $$
#
# ---
#
# ### **Common Uses:**
#
# 1. **In ANOVA**: To test if at least one group mean is significantly different.
# 2. **Variance Comparison**: To test if two samples come from populations with equal variances.
#
# ---
#
# ### **Hypotheses Example in ANOVA:**
#
# * **H₀**: All group means are equal.
# * **H₁**: At least one group mean is different.
#
# If the F-statistic is large (and p-value is small), we **reject H₀**.
#
# ---
#
# ##Practical Question ##
#
# ##Q1) Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and  interpret the results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs a two-tailed Z-test comparing sample mean to population mean.

    Parameters:
    sample (list or array): Sample data
    pop_mean (float): Known population mean
    pop_std (float): Known population standard deviation
    alpha (float): Significance level (default 0.05)

    Returns:
    z_score, p_value, interpretation
    """
    sample_mean = np.mean(sample)
    n = len(sample)
    standard_error = pop_std / np.sqrt(n)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_score)))

    # Interpretation
    if p_value < alpha:
        interpretation = "Reject the null hypothesis: significant difference."
    else:
        interpretation = "Fail to reject the null hypothesis: no significant difference."

    return z_score, p_value, interpretation


# Example data
sample_data = [105, 110, 98, 95, 102, 100, 108, 112, 99, 101]
population_mean = 100
population_std_dev = 15
significance_level = 0.05

# Perform Z-test
z, p, result = z_test(sample_data, population_mean, population_std_dev, significance_level)

print(f"Sample mean = {np.mean(sample_data):.2f}")
print(f"Z-score = {z:.3f}")
print(f"P-value = {p:.4f}")
print(f"Result: {result}")
# Out:
# Sample mean = 103.00
# Z-score = 0.632
# P-value = 0.5271
# Result: Fail to reject the null hypothesis: no significant difference.

# %% [markdown]
# ##Q2) Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
#
# Ans:

# %%
import numpy as np
from scipy.stats import ttest_ind

# Set random seed for reproducibility
np.random.seed(0)

# Simulate random data for two groups
group1 = np.random.normal(loc=100, scale=10, size=40)  # Mean=100, SD=10, n=40
group2 = np.random.normal(loc=105, scale=10, size=40)  # Mean=105, SD=10, n=40

# Perform two-sample t-test (independent samples)
t_statistic, p_value = ttest_ind(group1, group2)

# Print results
print(f"Group 1 mean: {np.mean(group1):.2f}")
print(f"Group 2 mean: {np.mean(group2):.2f}")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis — significant difference between groups.")
else:
    print("Result: Fail to reject the null hypothesis — no significant difference between groups.")
# Out:
# Group 1 mean: 103.13
# Group 2 mean: 101.26
# T-statistic: 0.8692
# P-value: 0.3874
# Result: Fail to reject the null hypothesis — no significant difference between groups.

# %% [markdown]
# ##Q3)Implement a one-sample Z-test using Python to compare the sample mean with the population mean ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs a one-sample Z-test.

    Parameters:
    - sample: list or numpy array of sample data
    - pop_mean: known population mean
    - pop_std: known population standard deviation
    - alpha: significance level (default 0.05)

    Returns:
    - z_stat: calculated Z statistic
    - p_value: two-tailed p-value
    - interpretation: string interpretation of the result
    """
    sample_mean = np.mean(sample)
    n = len(sample)
    standard_error = pop_std / np.sqrt(n)

    # Calculate Z statistic
    z_stat = (sample_mean - pop_mean) / standard_error

    # Calculate two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    # Interpretation
    if p_value < alpha:
        interpretation = "Reject the null hypothesis: sample mean is significantly different."
    else:
        interpretation = "Fail to reject the null hypothesis: no significant difference."

    return z_stat, p_value, interpretation


# Example usage
sample_data = [102, 98, 105, 100, 97, 103, 101, 99, 104, 100]
population_mean = 100
population_std_dev = 5  # Known population standard deviation
alpha_level = 0.05

z_statistic, p_val, result = one_sample_z_test(sample_data, population_mean, population_std_dev, alpha_level)

print(f"Sample mean: {np.mean(sample_data):.2f}")
print(f"Z statistic: {z_statistic:.3f}")
print(f"P-value: {p_val:.4f}")
print(f"Result: {result}")
# Out:
# Sample mean: 100.90
# Z statistic: 0.569
# P-value: 0.5692
# Result: Fail to reject the null hypothesis: no significant difference.

# %% [markdown]
# ##Q4) Perform a two-tailed Z-test using Python and visualize the decision region on a plot ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample and population parameters
sample = [102, 98, 105, 100, 97, 103, 101, 99, 104, 100]
pop_mean = 100
pop_std = 5
alpha = 0.05  # Significance level

# Calculate sample mean and standard error
sample_mean = np.mean(sample)
n = len(sample)
standard_error = pop_std / np.sqrt(n)

# Calculate Z-score
z_score = (sample_mean - pop_mean) / standard_error

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.3f}")
print(f"P-value: {p_value:.4f}")

# Critical Z values for two-tailed test
z_critical_low = norm.ppf(alpha / 2)
z_critical_high = norm.ppf(1 - alpha / 2)

print(f"Critical Z-values: {z_critical_low:.3f}, {z_critical_high:.3f}")

# Plot normal distribution curve
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.figure(figsize=(10,6))
plt.plot(x, y, label='Standard Normal Distribution')

# Shade rejection regions
plt.fill_between(x, 0, y, where=(x <= z_critical_low), color='red', alpha=0.3, label='Rejection Region (Left)')
plt.fill_between(x, 0, y, where=(x >= z_critical_high), color='red', alpha=0.3, label='Rejection Region (Right)')

# Plot Z-score
plt.axvline(z_score, color='blue', linestyle='--', label=f'Z-score = {z_score:.3f}')

# Decorations
plt.title('Two-tailed Z-test Decision Regions')
plt.xlabel('Z value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# Interpretation
if p_value < alpha:
    print("Decision: Reject the null hypothesis — significant difference.")
else:
    print("Decision: Fail to reject the null hypothesis — no significant difference.")
# Out:
# Sample Mean: 100.90
# Z-score: 0.569
# P-value: 0.5692
# Critical Z-values: -1.960, 1.960
# Decision: Fail to reject the null hypothesis — no significant difference.

# %% [markdown]
# ##Q5) Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type1_type2_errors(mu0, mu1, sigma, n, alpha=0.05):
    """
    Calculate and visualize Type I and Type II errors for testing H0: mu=mu0 vs Ha: mu=mu1.

    Parameters:
    - mu0: mean under null hypothesis
    - mu1: mean under alternative hypothesis
    - sigma: population standard deviation (known)
    - n: sample size
    - alpha: significance level (Type I error rate)
    """
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical value for two-tailed test
    z_crit_low = norm.ppf(alpha / 2)
    z_crit_high = norm.ppf(1 - alpha / 2)

    # Critical values on original scale
    crit_low = mu0 + z_crit_low * se
    crit_high = mu0 + z_crit_high * se

    # Calculate Type II error (beta):
    # Probability of failing to reject H0 when Ha is true,
    # i.e., sample mean falls between critical values under Ha distribution
    beta = norm.cdf(crit_high, loc=mu1, scale=se) - norm.cdf(crit_low, loc=mu1, scale=se)

    # Plotting x range covering both distributions well
    x_min = min(mu0, mu1) - 4*se
    x_max = max(mu0, mu1) + 4*se
    x = np.linspace(x_min, x_max, 1000)

    # PDFs
    pdf_H0 = norm.pdf(x, mu0, se)
    pdf_Ha = norm.pdf(x, mu1, se)

    plt.figure(figsize=(12,6))

    # Plot distributions
    plt.plot(x, pdf_H0, label='Null Hypothesis H0', color='blue')
    plt.plot(x, pdf_Ha, label='Alternative Hypothesis Ha', color='green')

    # Shade Type I error regions (tails under H0)
    plt.fill_between(x, 0, pdf_H0, where=(x <= crit_low), color='red', alpha=0.3, label='Type I Error (α)')
    plt.fill_between(x, 0, pdf_H0, where=(x >= crit_high), color='red', alpha=0.3)

    # Shade Type II error region (middle area under Ha)
    plt.fill_between(x, 0, pdf_Ha, where=((x > crit_low) & (x < crit_high)), color='orange', alpha=0.3, label='Type II Error (β)')

    # Critical value lines
    plt.axvline(crit_low, color='black', linestyle='--', label='Critical Values')
    plt.axvline(crit_high, color='black', linestyle='--')

    plt.title('Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Type I error (α): {alpha:.3f}")
    print(f"Type II error (β): {beta:.3f}")
    print(f"Power of test (1 - β): {1 - beta:.3f}")

# Example usage:
plot_type1_type2_errors(mu0=100, mu1=105, sigma=10, n=30, alpha=0.05)
# Out:
# Type I error (α): 0.050
# Type II error (β): 0.218
# Power of test (1 - β): 0.782

# %% [markdown]
# ##Q6) Write a Python program to perform an independent T-test and interpret the results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import ttest_ind

# Sample data for two independent groups
group1 = [23, 20, 22, 21, 24, 25, 23, 22]
group2 = [30, 29, 31, 28, 27, 32, 30, 29]

# Perform independent t-test
t_stat, p_value = ttest_ind(group1, group2)

print(f"Group 1 mean: {np.mean(group1):.2f}")
print(f"Group 2 mean: {np.mean(group2):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret the result
alpha = 0.05  # significance level
if p_value < alpha:
    print("Result: Reject the null hypothesis — groups have significantly different means.")
else:
    print("Result: Fail to reject the null hypothesis — no significant difference between groups.")
# Out:
# Group 1 mean: 22.50
# Group 2 mean: 29.50
# T-statistic: -8.7305
# P-value: 0.0000
# Result: Reject the null hypothesis — groups have significantly different means.

# %% [markdown]
# ##Q7) Perform a paired sample T-test using Python and visualize the comparison results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import ttest_rel
import matplotlib.pyplot as plt

# Example paired data: before and after treatment
before = np.array([85, 90, 88, 75, 95, 89, 92, 84])
after = np.array([88, 94, 90, 78, 98, 91, 95, 87])

# Perform paired sample t-test
t_stat, p_value = ttest_rel(before, after)

# Print results
print(f"Before mean: {np.mean(before):.2f}")
print(f"After mean: {np.mean(after):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis — significant difference between before and after.")
else:
    print("Result: Fail to reject the null hypothesis — no significant difference.")

# Visualization
plt.figure(figsize=(8,5))

# Plot paired values connected by lines
for i in range(len(before)):
    plt.plot([1, 2], [before[i], after[i]], marker='o', color='gray')

# Plot group means
plt.plot(1, np.mean(before), marker='D', color='blue', label='Before Mean')
plt.plot(2, np.mean(after), marker='D', color='red', label='After Mean')

plt.xticks([1, 2], ['Before', 'After'])
plt.ylabel('Values')
plt.title('Paired Sample Comparison')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Before mean: 87.25
# After mean: 90.12
# T-statistic: -12.6886
# P-value: 0.0000
# Result: Reject the null hypothesis — significant difference between before and after.

# %% [markdown]
# ##Q8)Simulate data and perform both Z-test and T-test, then compare the results using Python ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import norm, t

# Seed for reproducibility
np.random.seed(42)

# Population parameters (known)
pop_mean = 100
pop_std = 15  # Known population std deviation

# Simulate sample data
sample_size = 30
sample = np.random.normal(loc=102, scale=pop_std, size=sample_size)

# Sample statistics
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)

# --- One-sample Z-test ---
standard_error_z = pop_std / np.sqrt(sample_size)
z_stat = (sample_mean - pop_mean) / standard_error_z
p_value_z = 2 * (1 - norm.cdf(abs(z_stat)))  # two-tailed

# --- One-sample T-test ---
standard_error_t = sample_std / np.sqrt(sample_size)
t_stat = (sample_mean - pop_mean) / standard_error_t
df = sample_size - 1
p_value_t = 2 * (1 - t.cdf(abs(t_stat), df=df))  # two-tailed

# Output results
print(f"Sample mean: {sample_mean:.2f}")
print(f"Sample std dev: {sample_std:.2f}\n")

print("Z-test results (using known population std):")
print(f"Z-statistic = {z_stat:.4f}")
print(f"P-value = {p_value_z:.4f}\n")

print("T-test results (using sample std):")
print(f"T-statistic = {t_stat:.4f}")
print(f"Degrees of freedom = {df}")
print(f"P-value = {p_value_t:.4f}\n")

# Interpretation
alpha = 0.05
print("Interpretation at α = 0.05:")

if p_value_z < alpha:
    print("- Z-test: Reject null hypothesis (significant difference).")
else:
    print("- Z-test: Fail to reject null hypothesis (no significant difference).")

if p_value_t < alpha:
    print("- T-test: Reject null hypothesis (significant difference).")
else:
    print("- T-test: Fail to reject null hypothesis (no significant difference).")
# Out:
# Sample mean: 99.18
# Sample std dev: 13.50
#
# Z-test results (using known population std):
# Z-statistic = -0.3002
# P-value = 0.7640
#
# T-test results (using sample std):
# T-statistic = -0.3336
# Degrees of freedom = 29
# P-value = 0.7411
#
# Interpretation at α = 0.05:
# - Z-test: Fail to reject null hypothesis (no significant difference).
# - T-test: Fail to reject null hypothesis (no significant difference).

# %% [markdown]
# ##Q9) Write a Python function to calculate the confidence interval for a sample mean and explain its significance ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for the sample mean.

    Parameters:
    - sample: list or numpy array of sample data
    - confidence: confidence level (default 0.95 for 95%)

    Returns:
    - (lower_bound, upper_bound): tuple representing the confidence interval
    """
    n = len(sample)
    mean = np.mean(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)  # Standard error of the mean

    # Degrees of freedom
    df = n - 1

    # t critical value for two-tailed test
    t_crit = t.ppf((1 + confidence) / 2, df)

    margin_of_error = t_crit * std_err

    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return lower_bound, upper_bound

# Example usage
sample_data = [12, 15, 14, 16, 13, 15, 14, 16, 15, 14]
conf_level = 0.95

lower, upper = confidence_interval(sample_data, conf_level)
print(f"{conf_level*100:.0f}% confidence interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% confidence interval: (13.50, 15.30)

# %% [markdown]
# ##Q10) Write a Python program to calculate the margin of error for a given confidence level using sample data ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import t

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for the sample mean.

    Parameters:
    - sample: list or numpy array of sample data
    - confidence: confidence level (default 0.95)

    Returns:
    - margin_of_error: the margin of error
    """
    n = len(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)  # Standard error

    df = n - 1  # Degrees of freedom
    t_crit = t.ppf((1 + confidence) / 2, df)  # t critical value

    return t_crit * std_err

# Example usage
sample_data = [23, 21, 19, 25, 22, 20, 24, 23, 21, 22]
confidence_level = 0.95

moe = margin_of_error(sample_data, confidence_level)
print(f"Margin of Error at {confidence_level*100:.0f}% confidence: {moe:.3f}")
# Out:
# Margin of Error at 95% confidence: 1.306

# %% [markdown]
# ##Q11) Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process ?
#
# Ans:

# %%
def bayes_theorem(prior, likelihood, false_positive_rate):
    """
    Calculate the posterior probability using Bayes' theorem.

    Parameters:
    - prior: P(H), prior probability of the hypothesis (disease)
    - likelihood: P(E|H), probability of evidence if hypothesis is true (sensitivity)
    - false_positive_rate: P(E|~H), probability of evidence if hypothesis is false

    Returns:
    - posterior: P(H|E), updated probability of hypothesis given evidence
    """
    # Probability of evidence P(E)
    prob_evidence = (likelihood * prior) + (false_positive_rate * (1 - prior))

    # Posterior probability P(H|E)
    posterior = (likelihood * prior) / prob_evidence

    return posterior

# Given values
prior_disease = 0.01
sensitivity = 0.99
false_positive_rate = 0.05

posterior_prob = bayes_theorem(prior_disease, sensitivity, false_positive_rate)
print(f"Posterior probability of having the disease given a positive test: {posterior_prob:.4f}")
# Out:
# Posterior probability of having the disease given a positive test: 0.1667

# %% [markdown]
# ##Q12)  Perform a Chi-square test for independence between two categorical variables in Python ?
#
# Ans?

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Contingency table of two categorical variables
# Example: Preference (A, B) vs Gender (Male, Female)
# Rows: Gender (Male, Female)
# Columns: Preference (A, B)
observed = np.array([[30, 10],  # Male counts
                     [20, 40]]) # Female counts

# Perform Chi-square test
chi2, p, dof, expected = chi2_contingency(observed)

print(f"Chi-square statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print("Result: Reject the null hypothesis — variables are dependent.")
else:
    print("Result: Fail to reject the null hypothesis — variables are independent.")
# Out:
# Chi-square statistic: 15.0417
# P-value: 0.0001
# Degrees of freedom: 1
# Expected frequencies:
# [[20. 20.]
#  [30. 30.]]
# Result: Reject the null hypothesis — variables are dependent.

# %% [markdown]
# ##Q13) Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data ?
#
# Ans:

# %%
import numpy as np

def calculate_expected_frequencies(observed):
    """
    Calculate expected frequencies for a Chi-square test.

    Parameters:
    - observed: 2D numpy array of observed counts

    Returns:
    - expected: 2D numpy array of expected counts
    """
    # Row totals and column totals
    row_totals = observed.sum(axis=1).reshape(-1, 1)
    col_totals = observed.sum(axis=0).reshape(1, -1)
    total = observed.sum()

    # Expected frequency = (row total * column total) / grand total
    expected = (row_totals @ col_totals) / total
    return expected

# Example observed data
observed = np.array([[30, 10],
                     [20, 40]])

expected = calculate_expected_frequencies(observed)
print("Observed Frequencies:\n", observed)
print("Expected Frequencies:\n", expected)
# Out:
# Observed Frequencies:
#  [[30 10]
#  [20 40]]
# Expected Frequencies:
#  [[20. 20.]
#  [30. 30.]]

# %% [markdown]
# ##Q14) Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import chisquare

# Observed frequencies (counts in categories)
observed = np.array([50, 30, 20])

# Expected frequencies (must sum to same total as observed)
expected = np.array([40, 40, 20])

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis — observed data does NOT fit the expected distribution.")
else:
    print("Result: Fail to reject the null hypothesis — observed data fits the expected distribution.")
# Out:
# Chi-square statistic: 5.0000
# P-value: 0.0821
# Result: Fail to reject the null hypothesis — observed data fits the expected distribution.

# %% [markdown]
# ##Q15) Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

def plot_chi_square(dfs, samples=10000):
    """
    Simulate and plot Chi-square distributions for given degrees of freedom.

    Parameters:
    - dfs: list of degrees of freedom
    - samples: number of random samples to simulate per df
    """
    plt.figure(figsize=(10, 6))

    x = np.linspace(0, 30, 500)

    for df in dfs:
        # PDF using scipy.stats chi2
        pdf = chi2.pdf(x, df)

        # Plot the theoretical PDF
        plt.plot(x, pdf, label=f"df = {df}")

        # Simulate random samples and plot histogram
        data = np.random.chisquare(df, size=samples)
        plt.hist(data, bins=50, density=True, alpha=0.3)

    plt.title("Chi-square Distribution (PDF and Simulated Samples)")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# Degrees of freedom to visualize
degrees_of_freedom = [1, 2, 5, 10]

plot_chi_square(degrees_of_freedom)

# %% [markdown]
# ##Q16) Implement an F-test using Python to compare the variances of two random samples ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import f

def f_test(sample1, sample2, alpha=0.05):
    """
    Perform an F-test to compare the variances of two samples.

    Parameters:
    - sample1, sample2: arrays or lists of sample data
    - alpha: significance level (default 0.05)

    Returns:
    - F_stat: computed F statistic
    - p_value: two-tailed p-value
    - conclusion: string interpreting the result
    """
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    # Calculate F statistic (ratio of larger variance to smaller variance)
    if var1 > var2:
        F_stat = var1 / var2
        dfn = len(sample1) - 1  # degrees of freedom numerator
        dfd = len(sample2) - 1  # degrees of freedom denominator
    else:
        F_stat = var2 / var1
        dfn = len(sample2) - 1
        dfd = len(sample1) - 1

    # Two-tailed p-value calculation
    p_value = 2 * min(f.cdf(F_stat, dfn, dfd), 1 - f.cdf(F_stat, dfn, dfd))
    p_value = min(p_value, 1)  # p-value can't exceed 1

    conclusion = ("Reject null hypothesis: variances are significantly different."
                  if p_value < alpha else
                  "Fail to reject null hypothesis: no significant difference in variances.")

    return F_stat, p_value, conclusion

# Example samples
np.random.seed(42)
sample1 = np.random.normal(loc=10, scale=5, size=30)
sample2 = np.random.normal(loc=10, scale=7, size=30)

F_stat, p_value, conclusion = f_test(sample1, sample2)
print(f"F-statistic: {F_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(conclusion)
# Out:
# F-statistic: 2.0978
# P-value: 0.0505
# Fail to reject null hypothesis: no significant difference in variances.

# %% [markdown]
# ##Q17) Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import f_oneway

# Sample data: three groups with different observations
group1 = np.array([23, 21, 19, 25, 22])
group2 = np.array([30, 29, 31, 28, 35])
group3 = np.array([27, 26, 24, 28, 30])

# Perform one-way ANOVA
f_stat, p_value = f_oneway(group1, group2, group3)

print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis — at least one group mean is significantly different.")
else:
    print("Result: Fail to reject the null hypothesis — no significant difference between group means.")
# Out:
# F-statistic: 16.1734
# P-value: 0.0004
# Result: Reject the null hypothesis — at least one group mean is significantly different.

# %% [markdown]
# ##Q18) Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway, sem, t

# Sample data: three groups
group1 = np.array([23, 21, 19, 25, 22])
group2 = np.array([30, 29, 31, 28, 35])
group3 = np.array([27, 26, 24, 28, 30])

groups = [group1, group2, group3]
group_labels = ['Group 1', 'Group 2', 'Group 3']

# Perform one-way ANOVA
f_stat, p_value = f_oneway(*groups)

print(f"ANOVA F-statistic: {f_stat:.4f}")
print(f"ANOVA P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: Reject null hypothesis — at least one group mean is different.")
else:
    print("Result: Fail to reject null hypothesis — no significant difference between means.")

# Plotting group means with 95% confidence intervals
means = [np.mean(g) for g in groups]
sems = [sem(g) for g in groups]
dfs = [len(g) - 1 for g in groups]
conf_intervals = []

for mean, se, df in zip(means, sems, dfs):
    t_crit = t.ppf(0.975, df)  # two-tailed 95% CI
    margin = t_crit * se
    conf_intervals.append(margin)

# Plot
plt.figure(figsize=(8,6))
plt.bar(group_labels, means, yerr=conf_intervals, capsize=10, color=['skyblue', 'salmon', 'lightgreen'])
plt.ylabel('Mean Value')
plt.title('Group Means with 95% Confidence Intervals')
plt.show()
# Out:
# ANOVA F-statistic: 16.1734
# ANOVA P-value: 0.0004
# Result: Reject null hypothesis — at least one group mean is different.

# %% [markdown]
# ##Q19)Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import shapiro, levene

def check_anova_assumptions(groups, alpha=0.05):
    """
    Check ANOVA assumptions: normality and equal variances.
    Independence must be ensured by study design.

    Parameters:
    - groups: list of arrays/lists, each containing data for one group
    - alpha: significance level for tests (default 0.05)

    Returns:
    - dict with test results for normality and equal variances
    """
    results = {'normality': {}, 'equal_variance': None, 'independence': 'Assumed by study design'}

    # Normality test per group
    for i, group in enumerate(groups, start=1):
        stat, p = shapiro(group)
        results['normality'][f'Group {i}'] = {
            'statistic': stat,
            'p_value': p,
            'normal': p > alpha
        }

    # Equal variance test (Levene's test)
    stat, p = levene(*groups)
    results['equal_variance'] = {
        'statistic': stat,
        'p_value': p,
        'equal_variance': p > alpha
    }

    return results

# Example usage
group1 = [23, 21, 19, 25, 22]
group2 = [30, 29, 31, 28, 35]
group3 = [27, 26, 24, 28, 30]

assumption_results = check_anova_assumptions([group1, group2, group3])

print("ANOVA Assumptions Check:")
for group, result in assumption_results['normality'].items():
    print(f"{group} normality: p = {result['p_value']:.4f} -> {'Normal' if result['normal'] else 'Not Normal'}")

eq_var = assumption_results['equal_variance']
print(f"Equal variances (Levene's test): p = {eq_var['p_value']:.4f} -> {'Equal variances' if eq_var['equal_variance'] else 'Variances differ'}")
print(f"Independence: {assumption_results['independence']}")
# Out:
# ANOVA Assumptions Check:
# Group 1 normality: p = 0.9998 -> Normal
# Group 2 normality: p = 0.4272 -> Normal
# Group 3 normality: p = 0.9998 -> Normal
# Equal variances (Levene's test): p = 0.9730 -> Equal variances
# Independence: Assumed by study design

# %% [markdown]
# ##Q20)Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results ?
#
# Ans:

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# Simulate sample data
np.random.seed(42)

# Factors
factor_A = ['Low', 'High']
factor_B = ['Control', 'Treatment']

# Create balanced data
data = []
for A in factor_A:
    for B in factor_B:
        # mean depends on factors and their interaction
        if A == 'Low' and B == 'Control':
            mu = 20
        elif A == 'Low' and B == 'Treatment':
            mu = 25
        elif A == 'High' and B == 'Control':
            mu = 22
        else:  # High + Treatment
            mu = 30

        # simulate 10 observations per group
        data.extend([(A, B, np.random.normal(mu, 3)) for _ in range(10)])

# Create DataFrame
df = pd.DataFrame(data, columns=['Factor_A', 'Factor_B', 'Response'])

# Perform two-way ANOVA
model = ols('Response ~ C(Factor_A) + C(Factor_B) + C(Factor_A):C(Factor_B)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)  # Type II ANOVA

print("Two-way ANOVA results:")
print(anova_table)

# Visualization: Interaction plot
plt.figure(figsize=(8,6))
sns.pointplot(x='Factor_A', y='Response', hue='Factor_B', data=df, dodge=True,
              markers=['o', 's'], capsize=.1, errwidth=1, palette='Set2')
plt.title('Interaction Plot: Factor A and Factor B')
plt.ylabel('Mean Response')
plt.show()
# Out:
# Two-way ANOVA results:
#                              sum_sq    df          F    PR(>F)
# C(Factor_A)              103.424652   1.0  14.986237  0.000438
# C(Factor_B)              203.358277   1.0  29.466623  0.000004
# C(Factor_A):C(Factor_B)  104.050396   1.0  15.076907  0.000424
# Residual                 248.447131  36.0        NaN       NaN
# <ipython-input-21-696c5ddc9aa7>:44: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   sns.pointplot(x='Factor_A', y='Response', hue='Factor_B', data=df, dodge=True,

# %% [markdown]
# ##Q21) Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

def plot_f_distribution(dfn_list, dfd_list):
    """
    Plot F-distribution PDFs for multiple degrees of freedom.

    Parameters:
    - dfn_list: list of numerator degrees of freedom
    - dfd_list: list of denominator degrees of freedom
    """
    x = np.linspace(0, 5, 500)
    plt.figure(figsize=(10,6))

    for dfn, dfd in zip(dfn_list, dfd_list):
        pdf = f.pdf(x, dfn, dfd)
        plt.plot(x, pdf, label=f'dfn={dfn}, dfd={dfd}')

    plt.title('F-distribution PDFs')
    plt.xlabel('F value')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example degrees of freedom to plot
dfn_values = [1, 5, 10]
dfd_values = [5, 10, 20]

plot_f_distribution(dfn_values, dfd_values)

# %% [markdown]
# ##Q22)  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means ?
#
# Ans:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# Sample data: 3 groups
group1 = np.array([23, 21, 19, 25, 22])
group2 = np.array([30, 29, 31, 28, 35])
group3 = np.array([27, 26, 24, 28, 30])

groups = [group1, group2, group3]
group_labels = ['Group 1', 'Group 2', 'Group 3']

# Perform one-way ANOVA
f_stat, p_value = f_oneway(*groups)

print(f"ANOVA F-statistic: {f_stat:.4f}")
print(f"ANOVA P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Result: Reject null hypothesis — at least one group mean differs.")
else:
    print("Result: Fail to reject null hypothesis — no significant difference between group means.")

# Visualize data with boxplots
plt.figure(figsize=(8,6))
plt.boxplot(groups, labels=group_labels, patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='blue'),
            medianprops=dict(color='red'))

plt.title('Boxplots of Groups')
plt.ylabel('Values')
plt.grid(axis='y')
plt.show()
# Out:
# ANOVA F-statistic: 16.1734
# ANOVA P-value: 0.0004
# Result: Reject null hypothesis — at least one group mean differs.
# <ipython-input-23-a0fb38c28f9f>:26: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=group_labels, patch_artist=True,

# %% [markdown]
# ##Q23) Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import ttest_ind

# Set seed for reproducibility
np.random.seed(0)

# Simulate data
group1 = np.random.normal(loc=50, scale=5, size=30)  # mean=50, sd=5, n=30
group2 = np.random.normal(loc=53, scale=5, size=30)  # mean=53, sd=5, n=30

# Perform two-sample independent t-test (assumes equal variances by default)
t_stat, p_value = ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: Reject null hypothesis — means are significantly different.")
else:
    print("Result: Fail to reject null hypothesis — no significant difference in means.")
# Out:
# T-statistic: 0.5068
# P-value: 0.6142
# Result: Fail to reject null hypothesis — no significant difference in means.

# %% [markdown]
# ##Q24) Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import chi2

# Sample data (simulated)
np.random.seed(0)
sample = np.random.normal(loc=0, scale=4, size=30)  # true variance = 16

# Sample statistics
n = len(sample)
sample_var = np.var(sample, ddof=1)

# Hypothesized population variance
sigma0_sq = 16  # for example

# Calculate test statistic
chi_stat = (n - 1) * sample_var / sigma0_sq

# Degrees of freedom
df = n - 1

# Calculate two-tailed p-value
p_value = 2 * min(chi2.cdf(chi_stat, df), 1 - chi2.cdf(chi_stat, df))

print(f"Sample variance: {sample_var:.4f}")
print(f"Chi-square statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: Population variance is significantly different from hypothesized variance.")
else:
    print("Fail to reject null hypothesis: No significant difference from hypothesized variance.")
# Out:
# Sample variance: 19.3716
# Chi-square statistic: 35.1110
# P-value: 0.4018
# Fail to reject null hypothesis: No significant difference from hypothesized variance.

# %% [markdown]
# ##Q25)Write a Python script to perform a Z-test for comparing proportions between two datasets or groups ?
#
# Ans:

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

def two_proportion_z_test(success_a, size_a, success_b, size_b, alpha=0.05):
    """
    Perform two-proportion Z-test.

    Parameters:
    - success_a: number of successes in group A
    - size_a: total observations in group A
    - success_b: number of successes in group B
    - size_b: total observations in group B
    - alpha: significance level (default 0.05)

    Returns:
    - z_stat: computed Z statistic
    - p_value: p-value of the test
    - conclusion: interpretation of result
    """
    count = np.array([success_a, success_b])
    nobs = np.array([size_a, size_b])

    z_stat, p_value = proportions_ztest(count, nobs)

    conclusion = ("Reject null hypothesis: proportions are significantly different."
                  if p_value < alpha else
                  "Fail to reject null hypothesis: no significant difference between proportions.")

    return z_stat, p_value, conclusion

# Example usage:
success_a = 45
size_a = 100

success_b = 30
size_b = 100

z_stat, p_value, conclusion = two_proportion_z_test(success_a, size_a, success_b, size_b)

print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(conclusion)
# Out:
# Z-statistic: 2.1909
# P-value: 0.0285
# Reject null hypothesis: proportions are significantly different.

# %% [markdown]
# ##Q26) Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import f
import matplotlib.pyplot as plt

# Simulate two datasets
np.random.seed(42)
data1 = np.random.normal(loc=0, scale=5, size=30)  # variance ~25
data2 = np.random.normal(loc=0, scale=3, size=30)  # variance ~9

# Calculate sample variances
var1 = np.var(data1, ddof=1)
var2 = np.var(data2, ddof=1)

# Determine which variance is larger (F-test requires ratio >= 1)
if var1 >= var2:
    f_stat = var1 / var2
    dfn, dfd = len(data1) - 1, len(data2) - 1
else:
    f_stat = var2 / var1
    dfn, dfd = len(data2) - 1, len(data1) - 1

# Calculate p-value for two-tailed test
p_value = 2 * min(f.cdf(f_stat, dfn, dfd), 1 - f.cdf(f_stat, dfn, dfd))

print(f"Variance of dataset 1: {var1:.4f}")
print(f"Variance of dataset 2: {var2:.4f}")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: variances are significantly different.")
else:
    print("Fail to reject null hypothesis: no significant difference in variances.")

# Visualization
x = np.linspace(0, 5, 500)
f_pdf = f.pdf(x, dfn, dfd)

plt.figure(figsize=(10,6))
plt.plot(x, f_pdf, label=f'F-distribution df1={dfn}, df2={dfd}')
plt.axvline(f_stat, color='red', linestyle='--', label=f'F-statistic = {f_stat:.2f}')
plt.fill_between(x, 0, f_pdf, where=(x >= f_stat), color='red', alpha=0.3)
plt.title('F-distribution and F-test Statistic')
plt.xlabel('F value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# Boxplots for variance visualization
plt.figure(figsize=(8,5))
plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'], patch_artist=True,
            boxprops=dict(facecolor='lightblue'), medianprops=dict(color='red'))
plt.title('Boxplots of the two datasets')
plt.ylabel('Values')
plt.grid(axis='y')
plt.show()
# Out:
# Variance of dataset 1: 20.2503
# Variance of dataset 2: 7.8026
# F-statistic: 2.5953
# P-value: 0.0124
# Reject null hypothesis: variances are significantly different.
# <ipython-input-27-9049dfbfe532>:53: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'], patch_artist=True,

# %% [markdown]
# ##Q27) Perform a Chi-square test for goodness of fit with simulated data and analyze the results ?
#
# Ans:

# %%
import numpy as np
from scipy.stats import chisquare

# Simulated observed frequencies (e.g., counts in categories)
observed = np.array([50, 30, 20, 40, 60])

# Expected proportions for each category (must sum to 1)
expected_proportions = np.array([0.25, 0.20, 0.15, 0.25, 0.15])

# Calculate expected frequencies based on total count
total_count = observed.sum()
expected = expected_proportions * total_count

# Perform Chi-square goodness-of-fit test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Observed frequencies: {observed}")
print(f"Expected frequencies: {expected.astype(int)}")
print(f"Chi-square statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: observed data does NOT fit the expected distribution.")
else:
    print("Fail to reject null hypothesis: observed data fits the expected distribution.")
# Out:
# Observed frequencies: [50 30 20 40 60]
# Expected frequencies: [50 40 30 50 30]
# Chi-square statistic: 37.8333
# P-value: 0.0000
# Reject null hypothesis: observed data does NOT fit the expected distribution.
